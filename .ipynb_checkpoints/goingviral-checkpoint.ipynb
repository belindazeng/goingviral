# %% [markdown]
# # Predicting Popularity: Using Text and Content Analysis to Examine Shared Characteristics of Popular Posts on Twitter

# %% [markdown]
# ### A CS109 Final Project by Belinda Zeng, Roseanne Feng, Yuqi Hou, and Zahra Mahmood

# %% [markdown]
# ![caption](https://studentshare.net/content/wp-content/uploads/2015/05/53a0e7d640b31_-_unknown-3-51047042.png)

# %% [markdown]
# ## Background and Motivation

# %% [markdown]
# Twitter (https://twitter.com) is a social network, real-time news media service, and micro-blogging service where users can use text, photos, and videos to express moments or ideas in 140-characters or less. These 140-character messages are called "tweets.” According to Twitter’s website, millions of tweets are shared in real time, every day. Registered users can read and post tweets, favorite other people’s tweets, retweet other people’s posts, favorite tweets, and follow other accounts. Unregistered users can read tweets from public accounts.
#
# In today's day and age of Twitter, popularity is measured in hearts, retweets, follows, and follow-backs. What posts get popular over time? What seems to resonate most with people? Do positive or negative sentiments invite more engagement? In this project, we use Twitter's publically available archive of content to  like to examine some of the shared characteristics of popular posts, including length of post, visual content, positivity, negativity.

# %% [markdown]
# ## Related Work

# %% [markdown]
# Our idea came from a desire to understand how movements such as #BlackLivesMatter and #Ferguson begin on Twitter as well as a general desire to know what makes a post popular. We chose to focus on Tweets on an individual level and to use natural language processing to be able to understand and predict what makes posts popular.
#
# One paper that is related to our work is a paper from Cornell titled, [The effect of wording on message propagation: Topic- and author-controlled natural experiments on Twitter](https://chenhaot.com/pages/wording-for-propagation.html), which compaired pairs of tweets containing the same url and written by the same user but employing different wording to see which version attracted more retweets. Twitter itself has published research on [What fuels a Tweet’s engagement?](https://blog.twitter.com/2014/what-fuels-a-tweets-engagement) Their research found that adding video, links and photos all result in an increase in the number of retweets and even breaking down those results by industry. Inspired by previous research, we sought to include sentiment analysis in our understanding of what made a Tweet popular.

# %% [markdown]
# ## Initial Questions

# %% [markdown]
# 1. How does the distribution of retweets and hearts vary for a post depending on the time of day when the tweet is created?
# 2. How does positive and negative sentiment affect popularity?
# 3. What Tweets do we think will become popular?

# %% [markdown]
# ## Data

# %% [markdown]
# This data is publicly available via the Twitter Static API that gets queries based on specific parameters. We limited the data set to look at tweets within a specified period of time. We are storing the data in CSV files for now. To reduce file-sizes, we will try to have multiple CSVs so that we don't load too much data into memory. If data exceeds computer memory, we will consider AWS/SQL database alternatives.

# %% [markdown]
# ### Scraping

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
import csv

# %%
from collections import Counter
import ast

# %% [markdown]
# Set up oauth and a app on Twitter (to getthe consumer key & secret and access token and secret)

# %%
# great resource where I got all this 
# http://marcobonzanini.com/2015/03/02/mining-twitter-data-with-python-part-1/

import tweepy
import json
from tweepy import OAuthHandler

# %run api-keys.py # run any python script and load all of its data directly into the interactive namespace
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %% [markdown]
# Our initial approach is to create a random sample that consists of 1% of tweets. This involves using tweepy and the sample call from the Twitter API.

# %% [markdown]
# ```python
# # final, final version
#
# from tweepy import Stream
# from tweepy.streaming import StreamListener
#
# # get retweet status
# def try_retweet(status, attribute):
#     try:
#         if getattr(status, attribute):
#             return True
#     except AttributeError:
#         return None
#
# # function that tries to get attribute from object
# def try_get(status, attribute):
#     try:
#         return getattr(status, attribute).encode('utf-8')
#     except AttributeError:
#         return None
#
# # open csv file
# csvFile = open('smallsample.csv', 'a')
#
# # create csv writer
# csvWriter = csv.writer(csvFile)
#
# class MyListener(StreamListener):
#
#     def on_status(self, status):
#         try:
#             # save relevant components of the tweet
#
#             # get and sanitize hashtags
#             hashtags = status.entities['hashtags']
#             hashtag_list = []
#             for el in hashtags:
#                 hashtag_list.append(el['text'])
#             hashtag_count = len(hashtag_list)
#
#             # get and sanitize urls
#             urls = status.entities['urls']
#             url_list = []
#             for el in urls:
#                 url_list.append(el['url'])
#             url_count = len(url_list)
#
#             # get and sanitize user_mentions
#             user_mentions = status.entities['user_mentions']
#             mention_list = []
#             for el in user_mentions:
#                 mention_list.append(el['screen_name'])
#             mention_count = len(mention_list)
#             # save it all as a tweet
#             tweet = [status.created_at, status.text.encode('utf-8'), status.place, status.lang, status.coordinates,
#               hashtag_list, url_list, mention_list,
#               hashtag_count, url_count, mention_count,
#               try_get(status, 'possibly_sensitive'),
#               status.favorite_count, status.favorited, status.retweet_count, status.retweeted,
#               try_retweet(status,'retweeted_status'),
#               try_get(status.user, 'statuses_count'),
#               try_get(status.user, 'favourites_count'),
#               try_get(status.user, 'followers_count'),
#               try_get(status.user, 'description'),
#               try_get(status.user, 'location')]
#
#             # write to csv
#             csvWriter.writerow(tweet)
#         except BaseException as e:
#             print("Error on_data: %s" % str(e))
#         return True
#
#     # tell us if there's an error
#     def on_error(self, status):
#         print(status)
#         return True
#
# twitter_stream = Stream(auth, MyListener())
# twitter_stream.sample()
# ```

# %% [markdown]
# From this point on, analysis will be done on previously scraped tweets, and there is no need to run the above scraping code.

# %%
tweetdf_small=pd.read_csv("tempdata/smallsample.csv", names=["created_at", "text", "place", "lang", "coordinates",
                                       "hashtags", "urls", "user_mentions", 
                                       "hashtag_count", "url_count", "mention_count",
                                       "possibly_sensitive", 
                                       "favorite_count", "favorited", "retweet_count", "retweeted",
                                       "retweeted_status", "user_statuses_count", "user_favorites_count",
                                       "user_follower_count", "user_description", "user_location"])
tweetdf_small.head(10)
# Out:
#             created_at                                               text place lang coordinates                    hashtags urls                          user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_count favorited  retweet_count retweeted retweeted_status  user_statuses_count  user_favorites_count  user_follower_count                                   user_description        user_location
# 0  2015-11-24 21:24:41  RT @AcWgst: Reminds me of the fairytail~♡ Matt...   NaN   en         NaN                          []   []                            [u'AcWgst']              0          0              1                 NaN               0     False              0     False             True                  NaN                   NaN                  NaN  I love music, art, history, current events, WD...           California
# 1  2015-11-24 21:24:41  ドラゴンスラッシュってスマホゲーらしいのだけれどスクリーンショットだけを見てるとほんとヴァニ...   NaN   ja         NaN                          []   []                                     []              0          0              0                 NaN               0     False              0     False              NaN                  NaN                   NaN                  NaN                                                NaN                   県北
# 2  2015-11-24 21:24:41                                    やられたでや\n石神さん状態w   NaN   ja         NaN                          []   []                                     []              0          0              0                 NaN               0     False              0     False              NaN                  NaN                   NaN                  NaN                          味楽一条通り店。時々有明 故に我はエロティカセブン               土田 みさと
# 3  2015-11-24 21:24:41  #UKVOTY1D #MTVStars One Direction (MARO) Nicki...   NaN   sl         NaN  [u'UKVOTY1D', u'MTVStars']   []                                     []              2          0              0                 NaN               0     False              0     False              NaN                  NaN                   NaN                  NaN                                                NaN                  NaN
# 4  2015-11-24 21:24:41  RT @WhylmSingle: I WILL LOOK FOR YOU, I WILL F...   NaN   en         NaN                          []   []                       [u'WhylmSingle']              0          0              1                 NaN               0     False              0     False             True                  NaN                   NaN                  NaN  Electronic music producer/vocalist, PR/AR mana...            Miami, FL
# 5  2015-11-24 21:24:41  RT @higeorgeshelley: If u guys vote enough ton...   NaN   en         NaN                          []   []                   [u'higeorgeshelley']              0          0              1                 NaN               0     False              0     False             True                  NaN                   NaN                  NaN                                 I wanna runaway...  my own little world
# 6  2015-11-24 21:24:41              I Been Sleeping On @gilliedakid He 🔥   NaN   en         NaN                          []   []                       [u'gilliedakid']              0          0              1                 NaN               0     False              0     False              NaN                  NaN                   NaN                  NaN  FMOI @quicktriggap Blessed Basketball Bigman S...               Philly
# 7  2015-11-24 21:24:41       RT @awwmyloueh: @izaynie93 I'm proud of you!   NaN   en         NaN                          []   []          [u'awwmyloueh', u'izaynie93']              0          0              2                 NaN               0     False              0     False             True                  NaN                   NaN                  NaN  sometimes I add too little milk to my coffee a...             zquad ◡̈
# 8  2015-11-24 21:24:41  RT @CaronPeirson: @CleanDropMobile Let's clink...   NaN   en         NaN           [u'DigiBlogChat']   []  [u'CaronPeirson', u'CleanDropMobile']              1          0              2                 NaN               0     False              0     False             True                  NaN                   NaN                  NaN  CleanDrop  a mobile app for #foodies who deman...                  USA
# 9  2015-11-24 21:24:41  RT @JosAntonioNez: Dentro de 1 mes todo el mun...   NaN   es         NaN                          []   []                     [u'JosAntonioNez']              0          0              1                 NaN               0     False              0     False             True                  NaN                   NaN                  NaN  Del 97. Hermana de la Macarena. Auxiliar de En...                  NaN

# %%
tweetdf_small.shape
# Out:
# (52766, 22)

# %%
# make sure there are no missing retweet count
tweetdf_missing = tweetdf_small[tweetdf_small['retweet_count'] != 0] 
tweetdf_missing.shape
# Out:
# (0, 22)

# %% [markdown]
# As we can see, the retweet count and favorite count are always 0. This is because we're using the live streaming API and, as a result, we're scraping the tweets as they are tweeted. At this point, all the tweets have retweet count 0 and favorite count 0 since they were literally just posted! That is, unless the tweet posted is actually a retweet...
#
# To solve the problem of brand new tweets, we used retweets to get the original tweet. This also ensures that our model isn't thrown off when someone with a huge follower count retweets something. Finally, we made sure not to consider the same tweet text twice.

# %% [markdown]
# ### Get Original Retweets

# %% [markdown]
# The following function updates the way we use the tweepy streaming API. We first detect if the tweet we're looking at is actually a retweet of something. If so, we then get the original tweet and save that to our csv.

# %% [markdown]
# ```python
# # only save information for retweets
#
# from tweepy import Stream
# from tweepy.streaming import StreamListener
#
# # get retweet status
# def try_retweet(status, attribute):
#     try:
#         if getattr(status, attribute):
#             return True
#     except AttributeError:
#         return None
#
# # get country status
# def try_country(status, attribute):
#     if getattr(status, attribute) != None:
#         place = getattr(status, attribute)
#         return place.country
#     return None
#
# # get city status
# def try_city(status, attribute):
#     if getattr(status, attribute) != None:
#         place = getattr(status, attribute)
#         return place.full_name
#     return None
#
# # function that tries to get attribute from object
# def try_get(status, attribute):
#     try:
#         return getattr(status, attribute).encode('utf-8')
#     except AttributeError:
#         return None
#
# # open csv file
# csvFile = open('originalsample.csv', 'a')
#
# # create csv writer
# csvWriter = csv.writer(csvFile)
#
# class MyListener(StreamListener):
#
#     def on_status(self, status):
#         try:
#             # if this represents a retweet
#             if try_retweet(status,'retweeted_status'):
#                 status = status.retweeted_status
#
#                 # get and sanitize hashtags
#                 hashtags = status.entities['hashtags']
#                 hashtag_list = []
#                 for el in hashtags:
#                     hashtag_list.append(el['text'])
#                 hashtag_count = len(hashtag_list)
#
#                 # get and sanitize urls
#                 urls = status.entities['urls']
#                 url_list = []
#                 for el in urls:
#                     url_list.append(el['url'])
#                 url_count = len(url_list)
#
#                 # get and sanitize user_mentions
#                 user_mentions = status.entities['user_mentions']
#                 mention_list = []
#                 for el in user_mentions:
#                     mention_list.append(el['screen_name'])
#                 mention_count = len(mention_list)
#
#                 # save it all as a tweet
#                 tweet = [status.id, status.created_at, try_country(status, 'place'), try_city(status, 'place'), status.text.encode('utf-8'), status.lang,
#                   hashtag_list, url_list, mention_list,
#                   hashtag_count, url_count, mention_count,
#                   try_get(status, 'possibly_sensitive'),
#                   status.favorite_count, status.favorited, status.retweet_count, status.retweeted,
#                   status.user.statuses_count,
#                   status.user.favourites_count,
#                   status.user.followers_count,
#                   try_get(status.user, 'description'),
#                   try_get(status.user, 'location'),
#                   try_get(status.user, 'time_zone')]
#
#                 # write to csv
#                 csvWriter.writerow(tweet)
#         except BaseException as e:
#             print("Error on_data: %s" % str(e))
#         return True
#
#     # tell us if there's an error
#     def on_error(self, status):
#         print(status)
#         return True
#
# twitter_stream = Stream(auth, MyListener())
# twitter_stream.sample()
# ```

# %% [markdown]
# Now we read into pandas.

# %%
tweetdf=pd.read_csv("tempdata/originalsample.csv", names=["id", "created_at", "country", "city", "text", "lang",
                                       "hashtags", "urls", "user_mentions", 
                                       "hashtag_count", "url_count", "mention_count",
                                       "possibly_sensitive", 
                                       "favorite_count", "favorited", "retweet_count", "retweeted",
                                       "user_statuses_count", "user_favorites_count",
                                       "user_follower_count", "user_description", "user_location", "user_timezone"])
tweetdf.head(10)
# Out:
#                    id           created_at country city                                               text lang                                          hashtags                          urls       user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_count favorited  retweet_count retweeted  user_statuses_count  user_favorites_count  user_follower_count                                   user_description           user_location               user_timezone
# 0  669227044996124673  2015-11-24 18:52:15     NaN  NaN              Yo 💁🏼💟👌🏼 https://t.co/xLMaOl9QD4  und                                                []                            []                  []              0          0              0                 NaN             270     False            288     False                10726                 18927                24429                                                NaN         Yucatán, México                 Mexico City
# 1  669328402453626880  2015-11-25 01:35:01     NaN  NaN  読者が生産者に会いに行く!『北海道食べる通信』初の読者ツアー開催 – 北海道ファンマガジン ...   ja                                                []  [u'https://t.co/w4GkSYLhoz']                  []              0          1              0                 NaN               1     False              1     False                10176                   241                 1783  手稲駅南口直結徒歩１分　ハートビル法認定バリアフリーホテル　札幌市福祉のまちづくり条例適合ホ...  北海道札幌市手稲区手稲本町1条4丁目1番５号                     Sapporo
# 2  669335707505201152  2015-11-25 02:04:02     NaN  NaN  Not 1 shot, not 2 but 16. 16 tax payer purchas...   en       [u'LaquanMcDonald', u'sickofthesehashtags']                            []                  []              2          0              0                 NaN              25     False             23     False                15349                  1590                69865                         Sideways Slipper, ALEKESAM            The Universe  Pacific Time (US & Canada)
# 3  668550084976578560  2015-11-22 22:02:15     NaN  NaN  #comeeeheree @DooleyFunnyAf !! Had to get yo a...   en                                  [u'comeeeheree']                            []  [u'DooleyFunnyAf']              1          0              1                 NaN              24     False             28     False                11124                 15210                 4085  $quad Original | https://soundcloud.com/vanteb...                     NaN  Eastern Time (US & Canada)
# 4  669304504513380352  2015-11-25 00:00:03     NaN  NaN  Best #Thanksgiving memory? @KnucklePuckIL shar...   en                                 [u'Thanksgiving']  [u'https://t.co/IYC1jEOTeC']  [u'KnucklePuckIL']              1          1              1                 NaN             158     False             33     False                52246                  4509               526915  The nation’s leading voice on underground, alt...         Cleveland, Ohio  Eastern Time (US & Canada)
# 5  669178757417009152  2015-11-24 15:40:23     NaN  NaN  Muhammad kenapa handsome sangat 😍😂 https://t...   in                                                []                            []                  []              0          0              0                 NaN              91     False            173     False                58643                  8317                  733                                spread positivity ✨                      MY                Kuala Lumpur
# 6  669348536081850369  2015-11-25 02:55:01     NaN  NaN          rt for 5sos #MTVStars 5 Seconds of Summer   en                                     [u'MTVStars']                            []                  []              1          0              0                 NaN               3     False             21     False                 9816                     3                 3299  appreciating Michael mostly *ଘ(੭*ˊᵕˋ)੭* ੈ✩‧₊˚ ...     (Liv • Blain• Ant)   Eastern Time (US & Canada)
# 7  669335559425417216  2015-11-25 02:03:27     NaN  NaN  "Why didn't you do your homework over the holi...   en                                                []                            []                  []              0          0              0                 NaN             283     False            218     False                53293                   341               476765  just stahp. \r\n\r\nyou probably just ignore m...                     NaN  Eastern Time (US & Canada)
# 8  669339114974478336  2015-11-25 02:17:35     NaN  NaN  I think one of my favorite feelings is laughin...   en                                                []                            []                  []              0          0              0                 NaN               5     False              1     False                10140                  6619                  953  ⊱✿LIVE. .Like there's no midnight! ✿⊰ idfwu, t...                     NaN                         NaN
# 9  669348858418192384  2015-11-25 02:56:18     NaN  NaN  하루치하\r\n같이 팝시다\r\n#프로듀서_트친소 https://t.co/0ARAt...   ko  [u'\ud504\ub85c\ub4c0\uc11c_\ud2b8\uce5c\uc18c']                            []                  []              1          0              0                 NaN               0     False              7     False                22768                  1295                  159  아이마스와 하루치하 파는 잉여 유하치 / 쿄애니, 중력폭포, 디즈니 픽사도 파요!!...                     NaN  Pacific Time (US & Canada)

# %%
tweetdf.shape
# Out:
# (114509, 23)

# %% [markdown]
# ## Data wrangling

# %% [markdown]
# ### Filter for English language tweets

# %%
df_filtered = tweetdf[tweetdf['lang'] == 'en']

# %%
df_filtered.shape
# Out:
# (57079, 23)

# %% [markdown]
# ### Filter for unique tweet ids

# %%
df_filtered.drop_duplicates(subset='id', take_last=True)
df_filtered.head()
# Out:
#                    id           created_at country city                                               text lang                                     hashtags                          urls       user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_count favorited  retweet_count retweeted  user_statuses_count  user_favorites_count  user_follower_count                                   user_description        user_location               user_timezone
# 2  669335707505201152  2015-11-25 02:04:02     NaN  NaN  Not 1 shot, not 2 but 16. 16 tax payer purchas...   en  [u'LaquanMcDonald', u'sickofthesehashtags']                            []                  []              2          0              0                 NaN              25     False             23     False                15349                  1590                69865                         Sideways Slipper, ALEKESAM         The Universe  Pacific Time (US & Canada)
# 3  668550084976578560  2015-11-22 22:02:15     NaN  NaN  #comeeeheree @DooleyFunnyAf !! Had to get yo a...   en                             [u'comeeeheree']                            []  [u'DooleyFunnyAf']              1          0              1                 NaN              24     False             28     False                11124                 15210                 4085  $quad Original | https://soundcloud.com/vanteb...                  NaN  Eastern Time (US & Canada)
# 4  669304504513380352  2015-11-25 00:00:03     NaN  NaN  Best #Thanksgiving memory? @KnucklePuckIL shar...   en                            [u'Thanksgiving']  [u'https://t.co/IYC1jEOTeC']  [u'KnucklePuckIL']              1          1              1                 NaN             158     False             33     False                52246                  4509               526915  The nation’s leading voice on underground, alt...      Cleveland, Ohio  Eastern Time (US & Canada)
# 6  669348536081850369  2015-11-25 02:55:01     NaN  NaN          rt for 5sos #MTVStars 5 Seconds of Summer   en                                [u'MTVStars']                            []                  []              1          0              0                 NaN               3     False             21     False                 9816                     3                 3299  appreciating Michael mostly *ଘ(੭*ˊᵕˋ)੭* ੈ✩‧₊˚ ...  (Liv • Blain• Ant)   Eastern Time (US & Canada)
# 7  669335559425417216  2015-11-25 02:03:27     NaN  NaN  "Why didn't you do your homework over the holi...   en                                           []                            []                  []              0          0              0                 NaN             283     False            218     False                53293                   341               476765  just stahp. \r\n\r\nyou probably just ignore m...                  NaN  Eastern Time (US & Canada)

# %%
df_filtered.shape
# Out:
# (57079, 23)

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# After scraping tweets from the Twitter Streaming API, we use that data to build a feature list that we use to predict how popular an individual tweet will be, measured by a composite score based on the amount of retweets and hearts. We will also use metadata to help us analyze trends in the data, for example if there is a correlation between time of day and retweets.

# %% [markdown]
# ### Updates
#
# **11/30 - 12/1 (Yuqi)**
#
# Initial exploratory analysis regarding popularity score and hashtags done. It seems like we should rethink our current formula for popularity because the histogram gives extreme strange results and the max score is really high. Need to look into why that might be.
#
# All of the correlations that were done between popularity score and other factors came up significant. Could this be due to the large dataset that we are using? Should we be worried about things being labeled as significant not because it actually is significant but because there is so much data that small variations become significant?
#
# Also, noticed that some tweets are longer than 140 characters, and I'm not sure why that is either. Further data wrangling probably needed.
#
# **12/4 (Yuqi)** Tweets that have emojiis are converted into characters that's throwing off tweet length
#
# **12/7 - Yuqi** Took out analysis on how trending topics affects tweets
#
# **12/9 - Yuqi & Roseanne** Noticed that z-scoring retweet count and favorite count actually make the standard deviation larger. We also noticed that taking the log of popularity unstandardized gave us the same distribution as taking the log of popularity standardized. It seems like taking the log of our popularity score made a larger impact than standardizing the scores did.

# %% [markdown]
# # Popularity Score

# %% [markdown]
# This is the response variable that we are trying to predict using various features of a tweet. The score was originally calculated by adding raw retweet count and favorite counts together, but after some exploratory analysis we chose to z-score retweet and favorite counts.

# %% [markdown]
# ## Raw Popularity Score

# %%
popularity = [retweets + favs for retweets, favs in zip(df_filtered.retweet_count, df_filtered.favorite_count)]

# %%
# add popularity column to df
df_filtered.loc[:,'popularity']=popularity 
df_filtered.shape
# Out:
# (57079, 24)

# %%
dftouse = df_filtered.reset_index()
dftouse.head()
# Out:
#    index                  id           created_at country city                                               text lang                                     hashtags                          urls       user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_count favorited  retweet_count retweeted  user_statuses_count  user_favorites_count  user_follower_count                                   user_description        user_location               user_timezone  \
# 0      2  669335707505201152  2015-11-25 02:04:02     NaN  NaN  Not 1 shot, not 2 but 16. 16 tax payer purchas...   en  [u'LaquanMcDonald', u'sickofthesehashtags']                            []                  []              2          0              0                 NaN              25     False             23     False                15349                  1590                69865                         Sideways Slipper, ALEKESAM         The Universe  Pacific Time (US & Canada)
# 1      3  668550084976578560  2015-11-22 22:02:15     NaN  NaN  #comeeeheree @DooleyFunnyAf !! Had to get yo a...   en                             [u'comeeeheree']                            []  [u'DooleyFunnyAf']              1          0              1                 NaN              24     False             28     False                11124                 15210                 4085  $quad Original | https://soundcloud.com/vanteb...                  NaN  Eastern Time (US & Canada)
# 2      4  669304504513380352  2015-11-25 00:00:03     NaN  NaN  Best #Thanksgiving memory? @KnucklePuckIL shar...   en                            [u'Thanksgiving']  [u'https://t.co/IYC1jEOTeC']  [u'KnucklePuckIL']              1          1              1                 NaN             158     False             33     False                52246                  4509               526915  The nation’s leading voice on underground, alt...      Cleveland, Ohio  Eastern Time (US & Canada)
# 3      6  669348536081850369  2015-11-25 02:55:01     NaN  NaN          rt for 5sos #MTVStars 5 Seconds of Summer   en                                [u'MTVStars']                            []                  []              1          0              0                 NaN               3     False             21     False                 9816                     3                 3299  appreciating Michael mostly *ଘ(੭*ˊᵕˋ)੭* ੈ✩‧₊˚ ...  (Liv • Blain• Ant)   Eastern Time (US & Canada)
# 4      7  669335559425417216  2015-11-25 02:03:27     NaN  NaN  "Why didn't you do your homework over the holi...   en                                           []                            []                  []              0          0              0                 NaN             283     False            218     False                53293                   341               476765  just stahp. \r\n\r\nyou probably just ignore m...                  NaN  Eastern Time (US & Canada)
#
#    popularity
# 0          48
# 1          52
# 2         191
# 3          24
# 4         501

# %% [markdown]
# ## Popularity Score Exploratory Analysis

# %% [markdown]
# The distribution of popularity is extremely right-tailed. Later we find that this is explained by the distribution of retweet counts and favorite counts are also extremely right-skewed.

# %%
plt.hist(dftouse['popularity'],bins=100)
plt.title("Distribution of Popularity")
plt.show()

# %%
dftouse['popularity'].describe()
# Out:
# count      57079.000000
# mean        4045.792078
# std        28128.481508
# min            1.000000
# 25%            8.000000
# 50%          152.000000
# 75%         1633.000000
# max      2204783.000000
# Name: popularity, dtype: float64

# %% [markdown]
# ## Rethinking how Popularity is Scored
# The huge standard deviation and extreme ranges suggest that we may need to rethink how we score popularity. We looked more closely at a statistical summary of retweet count and favorite count to decide if any standardization would be necessary.

# %% [markdown]
# ## Retweets

# %%
plt.hist(dftouse['retweet_count'],bins=100)
plt.title("Distribution of Favorite Counts")
plt.show()

# %%
dftouse['retweet_count'].describe()
# Out:
# count      57079.000000
# mean        1955.125037
# std        17166.453753
# min            1.000000
# 25%            5.000000
# 50%           82.000000
# 75%          774.000000
# max      1608753.000000
# Name: retweet_count, dtype: float64

# %%
retweet_stats = dftouse['retweet_count'].describe()
retweet_mean = retweet_stats[1]
retweet_std = retweet_stats[2]

# %% [markdown]
# ## Favorites

# %%
plt.hist(dftouse['favorite_count'],bins=100)
plt.title("Distribution of Favorite Counts")
plt.show()

# %%
dftouse['favorite_count'].describe()
# Out:
# count     57079.000000
# mean       2090.667040
# std       12133.274417
# min           0.000000
# 25%           2.000000
# 50%          55.000000
# 75%         728.500000
# max      738582.000000
# Name: favorite_count, dtype: float64

# %%
favorite_stats = dftouse['favorite_count'].describe()
favorite_mean = favorite_stats[1]
favorite_std = favorite_stats[2]

# %% [markdown]
# Given these statistics on retweet_count and favorite_count, we realize we want to standardize these two for use later on, otherwise since there are way more retweets than favorites, retweets would get weighted more heavily.

# %%
dftouse = dftouse.rename(columns={'retweet_count': 'retweet_unstandardized', 'favorite_count': 'favorite_unstandardized'})

# %% [markdown]
# ** Create standardized retweet_count and favorite_count **

# %% [markdown]
# We decided to use a z-score to standardize retweet counts and favorite counts before adding them together to create the composite popularity score. Using that method, we standardize retweet count and favorites by subtracting the mean and dividing by the standard deviation.

# %%
retweets = [(retweet_count - retweet_mean)/float(retweet_std) for retweet_count in dftouse['retweet_unstandardized']]

# %%
favorites = [(favorite_count - favorite_mean)/float(favorite_std) for favorite_count in dftouse['favorite_unstandardized']]

# %% [markdown]
# Now we add these as columns to our dftouse.

# %%
dftouse.loc[:,'retweet_count']=retweets

# %%
dftouse.loc[:,'favorite_count']=favorites

# %%
print dftouse.retweet_count.describe()
# Out:
# count    4.866900e+04
# mean              inf
# std               NaN
# min               inf
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               inf
# Name: retweet_count, dtype: float64

# %%
print dftouse.favorite_count.describe()
# Out:
# count    5.707900e+04
# mean     2.017702e-16
# std      1.000000e+00
# min     -1.723086e-01
# 25%     -1.721437e-01
# 50%     -1.677756e-01
# 75%     -1.122671e-01
# max      6.070013e+01
# Name: favorite_count, dtype: float64

# %% [markdown]
# Now we recalculate popularity, but in the same way as before.

# %%
popularity = [retweets + favs for retweets, favs in zip(dftouse.retweet_count, dftouse.favorite_count)]
dftouse.loc[:,'popularity']=popularity

# %%
dftouse['popularity'].describe()
# Out:
# count      57079.000000
# mean        4045.792078
# std        28128.481508
# min            1.000000
# 25%            8.000000
# 50%          152.000000
# 75%         1633.000000
# max      2204783.000000
# Name: popularity, dtype: float64

# %% [markdown]
# ## Transforming Popularity Score

# %% [markdown]
# The original histogram of raw popularity scores appeared to have an exponential distribution, so we transformed the data using a log transformation in order to make the relationship between the response variable, popularity, had the explanatory variables (features) more observable. The resulting histogram had reasonable values, so there was no need to further standardize the popularity score.

# %%
unstandardized_popularity = [retweets + favs for retweets, favs in zip(dftouse.retweet_unstandardized, dftouse.favorite_unstandardized)]
dftouse.loc[:,'unstandardized_popularity']=popularity

# %%
dftouse['logpopularity']=dftouse['popularity'].apply(np.log)
dftouse['logpopularity'].describe()
# Out:
# count    57079.000000
# mean         4.847862
# std          3.105456
# min          0.000000
# 25%          2.079442
# 50%          5.023881
# 75%          7.398174
# max         14.606140
# Name: logpopularity, dtype: float64

# %%
plt.hist(dftouse['logpopularity'])
plt.xlabel('Log Popularity Score')
plt.ylabel('Frequency')
plt.title('Distribution of Log Popularity Score')
plt.show()

# %% [markdown]
# ## Hashtag Analysis

# %% [markdown]
# References:
# - http://stackoverflow.com/questions/1894269/convert-string-representation-of-list-to-list-in-python
# - http://stackoverflow.com/questions/10201977/how-to-reverse-tuples-in-python
# - http://stackoverflow.com/questions/13925251/python-bar-plot-from-list-of-tuples/34013980#34013980

# %% [markdown]
# #### What fraction of tweets in the sample use hashtags?

# %%
num_tags_per_tweet = dftouse['hashtag_count']
tags_per_tweet = np.array(num_tags_per_tweet)
tagfrac = float(len(tags_per_tweet[tags_per_tweet>0]))/float(len(tags_per_tweet))
print str(tagfrac)+" of tweets in the sample use one or more hashtags."
# Out:
# 0.264458031851 of tweets in the sample use one or more hashtags.

# %%
plt.hist(tags_per_tweet)
plt.ylabel('Frequency')
plt.title('Histogram of Hashtags Used in Tweets')
plt.show()

# %% [markdown]
# #### Top 10 hashtags

# %% [markdown]
# First get a flattened list of all the hashtags used in the sample:

# %%
alltags=[] 
for i in dftouse['hashtags']: # grab all the tags and put them into a list
    tag = ast.literal_eval(i) # convert string representation of list to list 
    alltags.append(tag) 
hashtags = [item for sublist in alltags for item in sublist] # flatten out the nested list

# %% [markdown]
# Then make a bar plot of the 10 most commonly used hashtags:

# %%
hashfreq = Counter(hashtags) # get the frequency of appearing hashtags
commontags = hashfreq.most_common(10) # save the top ten most common hashtags
taglabels = zip(*commontags)[0][::-1] # reverse the tuples to go from most frequent to least frequent 
hashtaglabels = ['#'+i for i in taglabels] # add a pound sign in front of each tag to make it clear that it's a hashtag
y_pos = np.arange(len(hashtaglabels)) 
usefreq = zip(*commontags)[1][::-1] # get the frequency part of the tuple
plt.barh(y_pos, usefreq, align='center') # plot horizontal barplot
plt.yticks(y_pos, hashtaglabels) 
plt.title('Top 10 Occuring Hashtags')
plt.show()

# %% [markdown]
# #### List of Hashtags Associated with Highest Popularity Score Tweets

# %%
from scipy.stats.stats import pearsonr

# %%
print pearsonr(dftouse['hashtag_count'],dftouse['logpopularity'])
plt.scatter(dftouse['hashtag_count'],dftouse['logpopularity'])
plt.ylabel('Log Popularity Score')
plt.show()
# Out:
# (-0.10892141913397739, 3.6689503558630989e-150)

# %% [markdown]
# #### Correlation between length of tweet and popularity

# %%
tweet_len = [len(text) for text in dftouse['text']]
print pearsonr(tweet_len,dftouse['logpopularity'])
plt.scatter(tweet_len,dftouse['logpopularity'])
plt.ylabel('Log Popularity Score')
plt.show()
# Out:
# (0.0073939008846619298, 0.07731569319726922)

# %% [markdown]
# It seems that some tweets are longer than 140 characters because tweets using emojiis are converted into unicode characters, which is being counted into tweet length. The below text shows a tweet that uses emojiis. The distribution of tweet length appears fairly uniform so we decided not to remove emojii text from the analysis. In addition, fewer than 5.6% of our tweets went over the 140 character mark, so we decided that the effect was negligible.

# %% [markdown]
# #### Character Length and Emojiis

# %%
tweet_len_array = np.array(tweet_len)
idx = np.where(tweet_len_array > 140)[0].tolist()
df_filtered_by_length = dftouse['text'].filter(idx).copy()
df_over140 = df_filtered_by_length.reset_index()
df_over140['text'][0]
# Out:
# "Floridians are hilarious \xf0\x9f\x98\x82 it's not even 60\xf0\x9f\x8c\xa1 and a bunch of ppl acting like we going through the ice age... BOII https://t.co/SUl78SKfTN"

# %%
# number of tweets that use emojiis
float(len(idx))/float(len(dftouse))
# Out:
# 0.05594001296448781

# %% [markdown]
# #### Correlation between presence of links and popularity

# %% [markdown]
# Dataframe only has information about links and it would have been too complex to differntiate between images links and other links, so differentiating between images and other urls for this. It appears that having more than one link is correlated with decreased popularity scores.

# %%
print pearsonr(dftouse['url_count'],dftouse['logpopularity'])
plt.scatter(dftouse['url_count'],dftouse['logpopularity'])
plt.ylabel('Log Popularity Score')
plt.show()
# Out:
# (-0.10615609933212956, 1.0800313222611673e-142)

# %% [markdown]
# #### Correlation between user mentions and popularity

# %% [markdown]
# It appears as though increasing the number of user mentions is correlated with a decrease in popularity score.

# %%
print pearsonr(dftouse['mention_count'],dftouse['logpopularity'])
plt.scatter(dftouse['mention_count'],dftouse['logpopularity'])
plt.ylabel('Log Popularity Score')
plt.show()
# Out:
# (-0.19553248042388102, 0.0)

# %% [markdown]
# #### Correlation for number of retweets and hearts

# %% [markdown]
# There generally appears to be a positive correlation between retweet count and hearts.

# %%
print pearsonr(dftouse['retweet_count'],dftouse['favorite_count'])
plt.scatter(dftouse['retweet_count'],dftouse['favorite_count'])
plt.show()
# Out:
# (0.83853253023981866, 0.0)

# %% [markdown]
# ### Location
#
# **Update 12/4 (Yuqi)** Originally we had planned to do exploratory analysis on popular topics that people tweet about by city or state, but after taking a look at our data, we found that 3.2% of tweets were geo-tagged, so we ultimately chose to forego this analysis.

# %% [markdown]
# #### Fraction of Tweets that are Geo-tagged

# %%
totaltweets = float(len(dftouse['country'])) # total number of tweets in sample
countryfrac = float(sum(map(lambda r: int(isinstance(r, str)), dftouse['country'])))/totaltweets
cityfrac = float(sum(map(lambda r: int(isinstance(r, str)), dftouse['city'])))/totaltweets
print str(cityfrac)+" of tweets in the sample are geo-tagged with a city."
print str(countryfrac)+" of tweets in the sample are geo-tagged with a country."
# Out:
# 0.0320433083971 of tweets in the sample are geo-tagged with a city.
# 0.0320433083971 of tweets in the sample are geo-tagged with a country.

# %% [markdown]
# ### Post Time

# %%
from datetime import datetime
date_objects = [datetime.strptime(each, '%Y-%m-%d %H:%M:%S') for each in dftouse['created_at']]

# %% [markdown]
# #### When are tweets posted throughout the week?

# %% [markdown]
# Because we used the Twitter Streaming API, most of the tweets are posted on a Tuesday, since that's when we scraped the tweets. This is also the case for the spike in tweets posted between midnight and 4am (localized time).

# %%
day_objects = [each.weekday() for each in date_objects]
x_pos = Counter(day_objects).keys()
height = Counter(day_objects).values()
days = ('Sunday','Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday')
plt.bar(x_pos,height,align='center')
plt.xticks(x_pos, days) 
plt.ylabel("Frequency")
plt.title("Distribution of Tweets Throughout the Week")
plt.show()

# %% [markdown]
# #### When are tweets posted during the day?

# %%
hour_objects = [each.hour for each in date_objects]
plt.hist(hour_objects)
plt.show()

# %% [markdown]
# A histogram is helpful, but a polar histogram could possibly visualize our data in a more intuitive way.

# %%
def main():
    data = hour_objects
    axes = plot_clock(data)
    for ax in axes:
        realign_polar_xticks(ax)
    plt.show()

def realign_polar_xticks(ax):
    pass
    for theta, label in zip(ax.get_xticks(), ax.get_xticklabels()):
        theta = theta * ax.get_theta_direction() + ax.get_theta_offset()
        theta = np.pi/2 - theta
        y, x = np.cos(theta), np.sin(theta)
        if x >= 0.1:
            label.set_horizontalalignment('left')
        if x <= -0.1:
            label.set_horizontalalignment('right')
        if y >= 0.5:
            label.set_verticalalignment('bottom')
        if y <= -0.5:
            label.set_verticalalignment('top')

def plot_clock(data):
    def hour_formatAM(x, p):
        hour = x * 6 / np.pi
        return '{:0.0f}:00'.format(hour) if x > 0 else '12:00'

    def hour_formatPM(x, p):
        hour = x * 6 / np.pi
        return '{:0.0f}:00'.format(hour + 12) if x > 0 else '24:00'

    def plot(ax, theta, counts, formatter):
        colors = plt.cm.jet(theta / 12.0)
        ax.bar(theta, counts, width=np.pi/6, color=colors, alpha=0.5)
        ax.xaxis.set_major_formatter(tkr.FuncFormatter(formatter))

    plt.rcParams['font.size'] = 8

    bins = np.r_[0, 0.5:12, 12, 12.5:24,  23.99999]
    counts = np.histogram(data,bins)[0]

    counts[13] += counts[0]
    counts[-1] += counts[13]

    fig, axes = plt.subplots(ncols=2, figsize=(22, 12), dpi=200,
                             subplot_kw=dict(projection='polar'))
    fig.subplots_adjust(wspace=0.5)

    for ax in axes:
        ax.set(theta_offset=np.pi/2, theta_direction=-1,
               xticks=np.arange(0, np.pi*2, np.pi/6),
               yticks=np.arange(1, counts.max()))

    plot(axes[0], bins[1:13] * np.pi / 6, counts[1:13], hour_formatAM)
    plot(axes[1], bins[14:26] * np.pi / 6, counts[14:26], hour_formatPM)
    return axes

main()

# %% [markdown]
# #### Correlation between time of day and tweet popularity

# %% [markdown]
# There does not appear to be a clear relationship between the time of day that a tweet is created and its popularity score. There does appear to be some cyclical change, but it's hard to tell based on the correlation.

# %%
plt.scatter(hour_objects, dftouse['logpopularity'])
plt.show()

# %% [markdown]
# #### The distribution of retweets and favorites over time

# %% [markdown]
# We were unable to plot this graph using the standardized retweet count so we chose to display the relationship using unstandardized values.

# %%
plt.figure()
plt.plot_date(date_objects, dftouse['favorite_unstandardized'], alpha=.1, color='r')
plt.plot_date(date_objects, dftouse['retweet_unstandardized'], alpha=.1, color='b')
plt.show()

# %% [markdown]
# #### User's followers correlated with popularity

# %%
user_follower_count = dftouse['user_follower_count'] 
print pearsonr(user_follower_count,dftouse['logpopularity'])
plt.scatter(user_follower_count,dftouse['logpopularity'])
plt.show()
# Out:
# (0.22944156883908295, 0.0)

# %% [markdown]
# ### Sentiment Analysis

# %% [markdown]
# #### Determining positive/negative words

# %% [markdown]
# Using sentiment lookup dictionaries, score tweets based on how positive/negative they are.
#
# **11/29 - Roseanne**
# Used a basic list of positive/negative words to begin with, no weights or other information beyond positive/negative. Appears to miss a bunch of tokens (1812/892606 found).
#
# **12/1 - Roseanne**
# Tried LabMT, using code provided. Rate is a lot better (7016/892606).
#
# **12/4 - Roseanne**
# Realized number of tokens (892606) was total tokens instead of unique tokens (83093). Still a lot but more tokens found than expected. LabMT is probably the better choice, though.

# %%
#notes: Unicode in texts (probably emoticons? should we find a way to categorize those?)

#load dicts into lookup, map words to pos or neg value
#current dict: not sure where it's from?
#1812 of 83093 words in lookup.
lookup = {}
with open('positive.txt', 'r') as f:
    for line in f:
        word = line[:-1]
        lookup[word] = 1
with open('negative.txt', 'r') as f:
    for line in f:
        word = line[:-1]
        lookup[word] = -1

# uses LabMT for scoring, see http://neuro.imm.dtu.dk/wiki/LabMT
# 7016 of 83093 words in LabMT.
url = 'http://www.plosone.org/article/fetchSingleRepresentation.action?uri=info:doi/10.1371/journal.pone.0026752.s001'
labmt = pd.read_csv(url, skiprows=2, sep='\t', index_col=0)

# %%
import nltk
# you'll need to download NLTK resource: nltk.download()
# or use terminal: sudo python -m nltk.downloader -d /usr/local/share/nltk_data all

# %%
#text = reduce(lambda x,y: x+y, dftouse['text'].apply(lambda x: [x])) # list of strings, functionally identical to dftouse['text']
tweetstext = reduce(lambda x,y: x + '\n' + y, dftouse['text']) # string of concatenated texts, all

# %%
# notice: tokenizer puts punctuation as their own tokens, ex. separates hashtags, etc.
tokens = nltk.word_tokenize(tweetstext.decode('utf-8','ignore'))

# %%
print "Number of tokens:", len(tokens)
fdist = nltk.FreqDist(tokens)
utokens = fdist.keys()
print "Unique tokens:", len(utokens)
print "Tokens that appear only once:", len(fdist.hapaxes())
#fdist.most_common(50)
inlookup = []
notfoundlookup = []
inlabmt = []
notfoundlabmt = []
for key in utokens:
    if key in lookup.keys():
        inlookup.append(key)
    else:
        notfoundlookup.append(key)
    if key in labmt.index:
        inlabmt.append(key)
    else:
        notfoundlabmt.append(key)
print "{} of {} words in lookup.".format(len(inlookup), len(utokens))
print inlookup[:10]

print "{} of {} words in LabMT.".format(len(inlabmt), len(utokens))
print inlabmt[:10]
# Out:
# Number of tokens: 892606
# Unique tokens: 83093
# Tokens that appear only once: 54968
# 1812 of 83093 words in lookup.
# [u'foul', u'non-violent', u'uplifting', u'controversy', u'spotty', u'golden', u'insecurity', u'sinking', u'unjust', u'wrong']
# 7016 of 83093 words in LabMT.
# [u'woods', u'hanging', u'foul', u'screaming', u'wednesday', u'errors', u'cooking', u'kids', u'controversy', u'rebel']

# %%
fdist.hapaxes()[:10] #lots of links, Unicode included here, is it worth filtering out these/punctuation?
# Out:
# [u'November15nse',
#  u'//t.co/txCIDduWui',
#  u'-Reyna',
#  u'snippets',
#  u'heraldleader',
#  u'woods',
#  u'Warriors\U0001f3c0\u2728',
#  u'romeolondon',
#  u'//t.co/AYsw8Xh7Kf',
#  u'uncanny']

# %%
utokens_ = [x for x in utokens if x[:6] != '//t.co']
urltokens = [x for x in utokens if x[:6] == '//t.co']
print "Non-URL tokens:", len(utokens_)
# Out:
# Non-URL tokens: 58629

# %% [markdown]
# **12/4 - Roseanne**
#
# Scoring - build columns for scoring text, one on the raw text, one on text that ignores words not in our dictionary, and one that shows us which words are not in the dictionary.

# %%
# average of entire tweet over unigrams
average = labmt.happiness_average.mean()
happiness = (labmt.happiness_average - average).to_dict()

# this is amazingly inefficient sorry
def score(text):
    words = nltk.word_tokenize(text.decode('utf-8','ignore'))
    return sum([happiness.get(word.lower(), 0.0) for word in words]) / len(words)

def scoreNoNeutrals(text):
    words = nltk.word_tokenize(text.decode('utf-8','ignore'))
    notscored = [word for word in words if happiness.get(word.lower(), 0.0) == 0.0]
    return sum([happiness.get(word.lower(), 0.0) for word in words]) / max((len(words) - len(notscored)),1)

def scored(text):
    words = nltk.word_tokenize(text.decode('utf-8','ignore'))
    return [word for word in words if happiness.get(word.lower(), 0.0) != 0.0]

def notScored(text):
    words = nltk.word_tokenize(text.decode('utf-8','ignore'))
    return [word for word in words if happiness.get(word.lower(), 0.0) == 0.0]


dftouse['text'].apply(score).mean()
dftouse['sentiment'] = dftouse['text'].apply(score)
dftouse['sentimentnoneutrals'] = dftouse['text'].apply(scoreNoNeutrals)
dftouse['scored'] = dftouse['text'].apply(scored)
dftouse['notscored'] = dftouse['text'].apply(notScored)
dftouse[['text','sentiment', 'sentimentnoneutrals', 'scored', 'notscored']].head()
# Out:
#                                                 text  sentiment  sentimentnoneutrals                                             scored                                          notscored
# 0  Not 1 shot, not 2 but 16. 16 tax payer purchas...  -0.692050            -1.768573  [Not, shot, not, but, tax, purchased, bullets,...  [1, ,, 2, 16, ., 16, payer, delivering, bloode...
# 1  #comeeeheree @DooleyFunnyAf !! Had to get yo a...  -0.087836            -0.193240   [Had, to, get, yo, ass, him, until, he, see, it]  [#, comeeeheree, @, DooleyFunnyAf, !, !, ,, @,...
# 2  Best #Thanksgiving memory? @KnucklePuckIL shar...   0.421269             1.579760                [Best, Thanksgiving, memory, share]  [#, ?, @, KnucklePuckIL, theirs…, https, :, //...
# 3          rt for 5sos #MTVStars 5 Seconds of Summer  -0.039578            -0.071240                     [rt, for, Seconds, of, Summer]                             [5sos, #, MTVStars, 5]
# 4  "Why didn't you do your homework over the holi...   0.091428             0.162538  [Why, did, you, do, your, homework, over, the,...      [``, n't, ?, '', https, :, //t.co/L4q1XbK3yq]

# %% [markdown]
# **12/4 - Roseanne**
#
# Checking how our lookup and scoring is working.
#
# Sentiment score ranges from approx. -3 to 3, with a mean close to 0.1, or roughly neutral.
#
# Hapaxes (words that appear only once in the Tweets we're analyzing) are a surprisingly large percentage of our tokens (~55000 out of 83000). A lot of them are URLs (19812), which we can probably ignore, or include a Unicode character or formatting that caused the tokenizer to behave oddly. Would it be worth it to try to filter out punctuation, or manually add them to our lookup (ex. replace .!?s with spaces, or add tokens such as '...'. If we add them, how do we generate a score for them?)

# %%
print dftouse.sentiment.min(), dftouse.sentiment.max(), dftouse.sentiment.mean()
print dftouse.sentimentnoneutrals.min(), dftouse.sentimentnoneutrals.max(), dftouse.sentimentnoneutrals.mean()
# Out:
# -3.05523967912 3.06476032088 0.102592078984
# -3.81523967912 3.06476032088 0.193900521551

# %%
dftouse.loc[dftouse.sentimentnoneutrals==dftouse.sentimentnoneutrals.max()]
# Out:
#        index                  id           created_at        country          city             text lang hashtags urls user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_count favorited  retweet_count retweeted  user_statuses_count  user_favorites_count  user_follower_count           user_description user_location               user_timezone  popularity  sentiment  sentimentnoneutrals       scored notscored
# 18671  39443  669359555072106496  2015-11-25 03:38:48  United States  Florida, USA        HAPPINESS   en       []   []            []              0          0              0                 NaN               0     False              1     False                 4766                  2968                  954                        NaN           NaN                         NaN           1    3.06476              3.06476  [HAPPINESS]        []
# 35069  72876  669367742999437316  2015-11-25 04:11:20            NaN           NaN  11:11 happiness   en       []   []            []              0          0              0                 NaN               2     False              2     False                24639                 14053                13945  @closetedink: next to you           NaN  Eastern Time (US & Canada)           4    1.53238              3.06476  [happiness]   [11:11]

# %%
dftouse.loc[dftouse.sentimentnoneutrals==dftouse.sentimentnoneutrals.min()]
# Out:
#        index                  id           created_at        country                    city                          text lang hashtags                          urls user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_unstandardized favorited  retweet_unstandardized retweeted  user_statuses_count  user_favorites_count  user_follower_count          user_description user_location               user_timezone  popularity  retweet_count  favorite_count  sentiment  \
# 33143  69110  669366933209370625  2015-11-25 04:08:07  United States  Peppermill Village, MD  kill https://t.co/iZ5EgTnzM4   en       []  [u'https://t.co/iZ5EgTnzM4']            []              0          1              0                 NaN                        0     False                       1     False                 6716                  4169                  536  ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀march 16th ..     benjamin$  Eastern Time (US & Canada)           1      -0.113834       -0.172309   -0.95381
#
#        sentimentnoneutrals                      notscored
# 33143             -3.81524  [https, :, //t.co/iZ5EgTnzM4]

# %%
for word, freq in fdist.most_common(50):
    print word, score(word)
# Out:
# : 0.0
# https 0.0
# # 0.0
# . 0.0
# the -0.395239679123
# @ 0.0
# you 0.864760320877
# to -0.395239679123
# I 0.544760320877
# ! 0.0
# , 0.0
# a -0.135239679123
# and -0.155239679123
# of -0.435239679123
# '' 0.0
# is -0.195239679123
# for -0.155239679123
# in 0.124760320877
# ? 0.0
# 's -0.435239679123
# n't 0.0
# your 0.224760320877
# on 0.184760320877
# this -0.315239679123
# my 0.784760320877
# ; 0.0
# me 1.20476032088
# & 0.0
# that -0.435239679123
# it -0.355239679123
# `` 0.0
# with 0.344760320877
# be 0.304760320877
# do 0.384760320877
# - 0.0
# ... 0.0
# amp 0.0647603208766
# like 1.84476032088
# at -0.475239679123
# so -0.295239679123
# are -0.215239679123
# when -0.415239679123
# all 0.844760320877
# When -0.415239679123
# ) 0.0
# have 0.444760320877
# The -0.395239679123
# but -1.13523967912
# i 0.544760320877
# 'm 0.0

# %% [markdown]
# ###Bigrams

# %%
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(tokens)

# %%
# scoring the association
scored = finder.score_ngrams(bigram_measures.raw_freq)

# %%
print scored[:20]
# Out:
# [((u'https', u':'), 0.04331362325594943), ((u'amp', u';'), 0.003116716670064956), ((u'&', u'amp'), 0.0031021525734758674), ((u'!', u'!'), 0.0029475490866070807), ((u'.', u'https'), 0.0024837386260007214), ((u'I', u"'m"), 0.002004243753683036), ((u'.', u'#'), 0.0019515889429378695), ((u'#', u'MTVStars'), 0.0018944528717037528), ((u'do', u"n't"), 0.001818271443391597), ((u'-', u'https'), 0.0017768197838688067), ((u'!', u'https'), 0.0017286462336125906), ((u'#', u'ThanksgivingClapBack'), 0.0017185633975124522), ((u'http', u':'), 0.001598689679433031), ((u'!', u'#'), 0.0015303504569765384), ((u'Me', u':'), 0.0013242124744848231), ((u'in', u'the'), 0.0013186108988736353), ((u'ThanksgivingClapBack', u'https'), 0.0012838811300842701), ((u"''", u'#'), 0.001254752936906093), ((u':', u'https'), 0.0012457904159281924), ((u'#', u'ALDUBApproval'), 0.0011696089876160366)]

# %%
# finds most associated bigrams
top_bigrams = finder.nbest(bigram_measures.raw_freq, 20)

# %%
# define bigrams
bigrams = dftouse['text'].apply(lambda x: list(nltk.bigrams(nltk.word_tokenize(x.decode('utf-8','ignore')))))

# %%
# finds the most common 20
import string
from sklearn.feature_extraction import text 
stopwords=text.ENGLISH_STOP_WORDS
punctuation = string.punctuation[:6] + string.punctuation[7:]
filtered = list(punctuation) + ['https','http','//t.co'] + list(stopwords)
# filter bigrams
tokens_ = [x for x in tokens if x not in filtered]

# %% [markdown]
# **Plot distribution of bigram frequencies**

# %%
# find 50 most common bigrams
bigramfreq = nltk.FreqDist(nltk.bigrams(tokens_))
bigramfreq.most_common(20)
frequencies = [freq for bigram, freq in bigramfreq.items()]
# plot distribution
plt.hist(frequencies, bins=100)
plt.title("Distribution of Bigram Frequencies")
plt.show()

# %% [markdown]
# ** Count important bigrams **

# %%
bigrams_sorted = sorted(bigramfreq.items(), key=lambda x: -x[1])
print bigrams_sorted[:20]
# Out:
# [((u'I', u"'m"), 1789), ((u'One', u'Direction'), 963), ((u'MTVStars', u'One'), 856), ((u'ca', u"n't"), 670), ((u"''", u'ThanksgivingClapBack'), 625), ((u'I', u"n't"), 546), ((u'5', u'Seconds'), 530), ((u'It', u"'s"), 504), ((u"''", u'Me'), 475), ((u'I', u'love'), 461), ((u'MTVStars', u'5'), 455), ((u'wan', u'na'), 427), ((u'gon', u'na'), 400), ((u'ai', u"n't"), 399), ((u'Me', u'``'), 385), ((u'Do', u"n't"), 379), ((u'Seconds', u'Summer'), 350), ((u'I', u'want'), 330), ((u'I', u"'ll"), 326), ((u"''", u'``'), 315)]

# %%
# bigram is important if it's associated more than 50 times
important_bigrams = [(bigram, val) for bigram, val in bigrams_sorted if val >= 50]
len(important_bigrams)
# Out:
# 272

# %% [markdown]
# What percentage of our bigrams are important?

# %%
frac = len(important_bigrams) / float(len(bigrams))
print frac
# Out:
# 0.00476532525097

# %% [markdown]
# This gives us hope that the presence of bigrams won't throw off our calculations too badly.

# %% [markdown]
# ** Manual scoring differ from our unigram scores? **

# %%
# assign scores to what we think is appropriate
manual_scores = bigrams_sorted[:20]
bigrams_tuple = [str(bigram) for bigram, frequency in manual_scores]

# %% [markdown]
# We manually score the bigrams to see which are positive and negative.

# %%
bigramdf = pd.DataFrame.from_items([('bigrams', bigrams_tuple)])
manual_ratings = ["Pos", "Pos", "Pos", "Neg", "Neg", "Pos", "Neg", "Neg", "Pos", "Pos", "Pos", 
                  "Neg", "Neg", "Neg", "Neg", "Pos", "Pos", "Pos", "Pos", "Neg"]
bigramdf['manual_ratings']= manual_ratings
bigramdf.head(5)
# Out:
#                             bigrams manual_ratings
# 0                     (u'I', u"'m")            Pos
# 1            (u'One', u'Direction')            Pos
# 2             (u'MTVStars', u'One')            Pos
# 3                   (u'ca', u"n't")            Neg
# 4  (u"''", u'ThanksgivingClapBack')            Neg

# %% [markdown]
# Now we do some unigram scoring

# %%
# scoring function for lists of tokens
def scoreTokens(words):
    return sum([happiness.get(word.lower(), 0.0) for word in words]) / len(words)

def scoreNoNeutralsTokens(words):
    notscored = [word for word in words if happiness.get(word.lower(), 0.0) == 0.0]
    return sum([happiness.get(word.lower(), 0.0) for word in words]) / max((len(words) - len(notscored)),1)

# %%
bigrams_text = [[word1, word2] for (word1, word2), frequency in manual_scores]

# %% [markdown]
# Our unigram scores including neutrals.

# %%
# pass bigrams to score function
unigram_scores_neutrals = [sum([happiness.get(word.lower(), 0.0) for word in bigram]) / len(bigram) for bigram in bigrams_text]
# # print whether they're positive or neutral
unigram_bool_neutrals = ["Pos" if score > 0 else "Neg" for score in unigram_scores_neutrals]
bigramdf['unigram_ratings_neutrals']= unigram_bool_neutrals

# %% [markdown]
# Our unigram scores without neutrals

# %%
# pass bigrams to no neutrals score function
unigram_scores_no_neutrals = [scoreNoNeutralsTokens(bigram) for bigram in bigrams_text]
# print whether they're positive or neutral
unigram_bool_no_neutrals = ["Pos" if score > 0 else "Neg" for score in unigram_scores_neutrals]
bigramdf['unigram_ratings_no_neutrals']= unigram_bool_no_neutrals

# %% [markdown]
# Our bigramdf now includes manual_ratings, unigram_ratings with neutrals and unigram_ratings without neutrals.

# %%
bigramdf.head(5)
# Out:
#                             bigrams manual_ratings unigram_ratings_neutrals unigram_ratings_no_neutrals
# 0                     (u'I', u"'m")            Pos                      Pos                         Pos
# 1            (u'One', u'Direction')            Pos                      Pos                         Pos
# 2             (u'MTVStars', u'One')            Pos                      Pos                         Pos
# 3                   (u'ca', u"n't")            Neg                      Neg                         Neg
# 4  (u"''", u'ThanksgivingClapBack')            Neg                      Neg                         Neg

# %% [markdown]
# Calculate the accuracy of our unigram scoring

# %%
# calculate percent difference neutrals
bigramdf['neutral_manual_same'] = [ 1 if manual == neutral else 0 for manual, neutral in zip(
                                    bigramdf['manual_ratings'],
                                    bigramdf['unigram_ratings_neutrals'])]
neutralcount = bigramdf['neutral_manual_same'].sum()
# calculate percent difference no neutrals
neutralcount/float(len(bigramdf))
# Out:
# 0.9

# %% [markdown]
# This shows that our unigram scoring seems pretty accurate since 90% of our manual scoring of bigrams actually match our unigram scores. Now we see if this holds for our no neutrals scoring as wel.

# %%
# noneutral_manual_same
bigramdf['noneutral_manual_same'] = [ 1 if manual == neutral else 0 for manual, neutral in zip(
                                    bigramdf['manual_ratings'],
                                    bigramdf['unigram_ratings_no_neutrals'])]
noneutralcount = bigramdf['noneutral_manual_same'].sum()
noneutralcount/float(len(bigramdf))
# Out:
# 0.9

# %%
bigramdf
# Out:
#                              bigrams manual_ratings unigram_ratings_neutrals unigram_ratings_no_neutrals  neutral_manual_same  noneutral_manual_same
# 0                      (u'I', u"'m")            Pos                      Pos                         Pos                    1                      1
# 1             (u'One', u'Direction')            Pos                      Pos                         Pos                    1                      1
# 2              (u'MTVStars', u'One')            Pos                      Pos                         Pos                    1                      1
# 3                    (u'ca', u"n't")            Neg                      Neg                         Neg                    1                      1
# 4   (u"''", u'ThanksgivingClapBack')            Neg                      Neg                         Neg                    1                      1
# 5                     (u'I', u"n't")            Pos                      Pos                         Pos                    1                      1
# 6                 (u'5', u'Seconds')            Neg                      Neg                         Neg                    1                      1
# 7                     (u'It', u"'s")            Neg                      Neg                         Neg                    1                      1
# 8                     (u"''", u'Me')            Pos                      Pos                         Pos                    1                      1
# 9                    (u'I', u'love')            Pos                      Pos                         Pos                    1                      1
# 10               (u'MTVStars', u'5')            Pos                      Neg                         Neg                    0                      0
# 11                   (u'wan', u'na')            Neg                      Neg                         Neg                    1                      1
# 12                   (u'gon', u'na')            Neg                      Neg                         Neg                    1                      1
# 13                   (u'ai', u"n't")            Neg                      Neg                         Neg                    1                      1
# 14                    (u'Me', u'``')            Neg                      Pos                         Pos                    0                      0
# 15                   (u'Do', u"n't")            Pos                      Pos                         Pos                    1                      1
# 16           (u'Seconds', u'Summer')            Pos                      Pos                         Pos                    1                      1
# 17                   (u'I', u'want')            Pos                      Pos                         Pos                    1                      1
# 18                    (u'I', u"'ll")            Pos                      Pos                         Pos                    1                      1
# 19                    (u"''", u'``')            Neg                      Neg                         Neg                    1                      1

# %% [markdown]
# ### Trigrams

# %% [markdown]
# Now we see do the same thing with trigrams.

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(tokens)
# scoring the association
# scored = finder.score_ngrams(trigram_measures.raw_freq)
# print scored[:20]

# %%
# finds most associated trigrams
top_trigrams = finder.nbest(trigram_measures.raw_freq, 20)

# %%
# define trigrams
trigrams = dftouse['text'].apply(lambda x: list(nltk.trigrams(nltk.word_tokenize(x.decode('utf-8','ignore')))))

# %%
# finds the most common 20
tokens_ = [x for x in tokens if x not in filtered]

# %% [markdown]
# **Plot distribution of trigram frequencies**

# %%
# find 50 most common bigrams
trigramfreq = nltk.FreqDist(nltk.trigrams(tokens_))
trigramfreq.most_common(20)
frequencies = [freq for trigram, freq in trigramfreq.items()]
# plot distribution
plt.hist(frequencies, bins=100)
plt.title("Distribution of Trigram Frequencies")
plt.show()

# %% [markdown]
# ** Count important trigrams **

# %%
trigrams_sorted = sorted(trigramfreq.items(), key=lambda x: -x[1])
print trigrams_sorted[:20]
# Out:
# [((u'MTVStars', u'One', u'Direction'), 849), ((u'MTVStars', u'5', u'Seconds'), 409), ((u"''", u'Me', u'``'), 368), ((u'5', u'Seconds', u'Summer'), 349), ((u'I', u'ca', u"n't"), 220), ((u'Seconds', u'Of', u'Summer'), 177), ((u'5', u'Seconds', u'Of'), 177), ((u'gt', u'gt', u'gt'), 157), ((u'New', u'iPhone', u'winner'), 142), ((u'reply', u'enter', u'//t.co/t6vWuCDe26'), 141), ((u'winner', u'midnight', u'Gon'), 141), ((u'Gon', u'na', u'Twitter'), 141), ((u'midnight', u'Gon', u'na'), 141), ((u'iPhone', u'winner', u'midnight'), 141), ((u'na', u'Twitter', u'exclusive'), 141), ((u'RT', u'reply', u'enter'), 141), ((u'Twitter', u'exclusive', u'RT'), 141), ((u'exclusive', u'RT', u'reply'), 141), ((u'OH', u'MY', u'GOD'), 134), ((u'Christmas', u'coming', u'soon'), 125)]

# %%
# bigram is important if it's associated more than 50 times
important_trigrams = [(trigram, val) for trigram, val in trigrams_sorted if val >= 50]
len(important_trigrams)
# Out:
# 110

# %% [markdown]
# As before, the percentage of our trigrams that are important.

# %%
frac = len(important_trigrams) / float(len(trigrams))
print frac
# Out:
# 0.00192715359414

# %% [markdown]
# **Compare manual and unigram scores of trigrams.**

# %%
# assign scores to what we think is appropriate
manual_scores = trigrams_sorted[:20]
trigrams_tuple = [str(trigram) for trigram, frequency in manual_scores]

# %% [markdown]
# Manual scoring

# %%
trigramdf = pd.DataFrame.from_items([('trigrams', trigrams_tuple)])
manual_ratings = ["Pos", "Pos", "Pos", "Neg", "Neg", "Pos", "Neg", "Neg", "Pos", "Pos", "Pos", 
                  "Neg", "Neg", "Neg", "Neg", "Pos", "Pos", "Pos", "Pos", "Neg"]
trigramdf['manual_ratings']= manual_ratings
trigramdf.head(5)
# Out:
#                               trigrams manual_ratings
# 0  (u'MTVStars', u'One', u'Direction')            Pos
# 1      (u'MTVStars', u'5', u'Seconds')            Pos
# 2                (u"''", u'Me', u'``')            Pos
# 3        (u'5', u'Seconds', u'Summer')            Neg
# 4                (u'I', u'ca', u"n't")            Neg

# %% [markdown]
# Unigram scoring

# %% [raw]
# # scoring function for lists
# def score(words):
#     return sum([happiness.get(word.lower(), 0.0) for word in words]) / len(words)
#
# def scoreNoNeutrals(words):
#     notscored = [word for word in words if happiness.get(word.lower(), 0.0) == 0.0]
#     return sum([happiness.get(word.lower(), 0.0) for word in words]) / max((len(words) - len(notscored)),1)

# %%
trigrams_text = [[word1, word2, word3] for (word1, word2, word3), frequency in manual_scores]

# %% [markdown]
# Scoring with neutrals

# %%
# pass bigrams to score function
unigram_scores_neutrals = [sum([happiness.get(word.lower(), 0.0) for word in trigram]) / len(bigram) for trigram in trigrams_text]
# # print whether they're positive or neutral
unigram_bool_neutrals = ["Pos" if score > 0 else "Neg" for score in unigram_scores_neutrals]
trigramdf['unigram_ratings_neutrals']= unigram_bool_neutrals

# %% [markdown]
# Scoring without neutrals

# %%
# pass bigrams to no neutrals score function
unigram_scores_no_neutrals = [scoreNoNeutralsTokens(bigram) for bigram in bigrams_text]
# print whether they're positive or neutral
unigram_bool_no_neutrals = ["Pos" if score > 0 else "Neg" for score in unigram_scores_neutrals]
bigramdf['unigram_ratings_no_neutrals']= unigram_bool_no_neutrals

# %% [markdown]
# Accuracy of scoring with and without neutrals

# %%
# calculate percent difference neutrals
trigramdf['neutral_manual_same'] = [ 1 if manual == neutral else 0 for manual, neutral in zip(
                                    trigramdf['manual_ratings'],
                                    trigramdf['unigram_ratings_neutrals'])]
neutralcount = trigramdf['neutral_manual_same'].sum()
# noneutral_manual_same
bigramdf['noneutral_manual_same'] = [ 1 if manual == neutral else 0 for manual, neutral in zip(
                                    bigramdf['manual_ratings'],
                                    bigramdf['unigram_ratings_no_neutrals'])]
noneutralcount = bigramdf['noneutral_manual_same'].sum()
# calculate percent difference neutrals, and no neutrals
neutralcount/float(len(trigramdf)), noneutralcount/float(len(bigramdf))
# Out:
# (0.7, 0.7)

# %% [markdown]
# ###Unigram, Bigram, Trigram comparison

# %%
scoredunigrams = [(x, y, scoreNoNeutralsTokens([x])) for x,y in fdist.items() if y >= 20]

posunigrams = [(x,y,z) for x,y,z in scoredunigrams if z >= 1]
negunigrams = [(x,y,z) for x,y,z in scoredunigrams if z <= 1]
neuunigrams = [(x,y,z) for x,y,z in scoredunigrams if z < 1 and z > -1]

print "unigrams positive:", len(posunigrams), "negative:", len(negunigrams), "neutral:", len(neuunigrams)
# Out:
# unigrams positive: 741 negative: 2848 neutral: 2504

# %%
scoredbigrams = [(x, y, scoreNoNeutralsTokens(x)) for x,y in bigramfreq.items() if y >= 20]

posbigrams = [(x,y, z) for x,y,z in scoredbigrams if z >= 1]
negbigrams = [(x,y, z) for x,y,z in scoredbigrams if z <= 1]
neubigrams = [(x,y, z) for x,y,z in scoredbigrams if z < 1 and z > -1]

print "bigrams positive:", len(posbigrams), "negative:", len(negbigrams), "neutral:", len(neubigrams)
# Out:
# bigrams positive: 345 negative: 1327 neutral: 1235

# %%
scoredtrigrams = [(x, y, scoreNoNeutralsTokens(x)) for x,y in trigramfreq.items() if y >= 20]

postrigrams = [(x,y,z) for x,y,z in scoredtrigrams if z >= 1]
negtrigrams = [(x,y,z) for x,y,z in scoredtrigrams if z <= 1]
neutrigrams = [(x,y,z) for x,y,z in scoredtrigrams if z < 1 and z > -1]

print "trigrams positive:", len(postrigrams), "negative:", len(negtrigrams), "neutral:", len(neutrigrams)
# Out:
# trigrams positive: 214 negative: 829 neutral: 791

# %%
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(30, 30), 
                         tight_layout=True)

grams = [(1, scoredunigrams, 'unigrams'),
        (2, scoredbigrams, 'bigrams'),
        (3, scoredtrigrams, 'trigrams')]

for i, dist, name in grams:
    plt.subplot(3,1,i)
    flattened = reduce(lambda x,y: x+y, [[z]*y for x,y,z in dist])
    #plt.hist(plotpostri+plotnegtri+plotneutri, color=['b','r', 'g'], label=['positive', 'negative', 'neutral'])
    plt.hist(flattened)
    plt.title(name)

# %%
#grams = [(1, scoredunigrams, 'unigrams'),
#        (2, scoredbigrams, 'bigrams'),
#        (3, scoredtrigrams, 'trigrams')]

plt.figure()
for i, dist, name in grams:
    flattened = reduce(lambda x,y: x+y, [[z]*y for x,y,z in dist])
    #plt.hist(plotpostri+plotnegtri+plotneutri, color=['b','r', 'g'], label=['positive', 'negative', 'neutral'])
    plt.hist(flattened, alpha=0.2, label=name)
plt.legend(frameon=True)

# %%
color = ['b','r','g']
plt.figure()
for i, dist, name in grams:
    yscores = [z for x,y,z in dist]
    xvals = [i + (np.random.rand() - 0.5)/2. for y in yscores]
    plt.scatter(xvals, yscores, alpha=0.2, label=name, c=color[i-1])
plt.gca().axes.get_xaxis().set_ticks([])
plt.xticks([1.,2.,3.],['unigrams','bigrams','trigrams'])
plt.title('Distribution of sentiment scores over ngrams')
plt.ylabel('Sentiment')

# %% [markdown]
# #### Visual content

# %% [markdown]
# #### Length of post

# %% [markdown]
# # Prediction

# %% [markdown]
# **12/6 - Roseanne**
#
# Working on prediction. Note: HW5 prediction is used to predict if sentiment is positive or negative, but we want to use this to predict how popular something is, not sure how to do that. Xarray below was built on text, but we should probably be doing something like HW2 and using sentiment or sentimentnoneutrals as one of the factors instead. I have been doing too much text analysis.

# %%
dftouse.head()
# Out:
#    index                  id           created_at country city                                               text lang                                     hashtags                          urls       user_mentions  hashtag_count  url_count  mention_count  possibly_sensitive  favorite_unstandardized favorited  retweet_unstandardized retweeted  user_statuses_count  user_favorites_count  user_follower_count                                   user_description        user_location  \
# 0      2  669335707505201152  2015-11-25 02:04:02     NaN  NaN  Not 1 shot, not 2 but 16. 16 tax payer purchas...   en  [u'LaquanMcDonald', u'sickofthesehashtags']                            []                  []              2          0              0                 NaN                       25     False                      23     False                15349                  1590                69865                         Sideways Slipper, ALEKESAM         The Universe
# 1      3  668550084976578560  2015-11-22 22:02:15     NaN  NaN  #comeeeheree @DooleyFunnyAf !! Had to get yo a...   en                             [u'comeeeheree']                            []  [u'DooleyFunnyAf']              1          0              1                 NaN                       24     False                      28     False                11124                 15210                 4085  $quad Original | https://soundcloud.com/vanteb...                  NaN
# 2      4  669304504513380352  2015-11-25 00:00:03     NaN  NaN  Best #Thanksgiving memory? @KnucklePuckIL shar...   en                            [u'Thanksgiving']  [u'https://t.co/IYC1jEOTeC']  [u'KnucklePuckIL']              1          1              1                 NaN                      158     False                      33     False                52246                  4509               526915  The nation’s leading voice on underground, alt...      Cleveland, Ohio
# 3      6  669348536081850369  2015-11-25 02:55:01     NaN  NaN          rt for 5sos #MTVStars 5 Seconds of Summer   en                                [u'MTVStars']                            []                  []              1          0              0                 NaN                        3     False                      21     False                 9816                     3                 3299  appreciating Michael mostly *ଘ(੭*ˊᵕˋ)੭* ੈ✩‧₊˚ ...  (Liv • Blain• Ant)
# 4      7  669335559425417216  2015-11-25 02:03:27     NaN  NaN  "Why didn't you do your homework over the holi...   en                                           []                            []                  []              0          0              0                 NaN                      283     False                     218     False                53293                   341               476765  just stahp. \r\n\r\nyou probably just ignore m...                  NaN
#
#                 user_timezone  popularity  retweet_count  favorite_count  logpopularity  sentiment  sentimentnoneutrals                                             scored                                          notscored
# 0  Pacific Time (US & Canada)          48      -0.112552       -0.170248       3.871201  -0.692050            -1.768573  [Not, shot, not, but, tax, purchased, bullets,...  [1, ,, 2, 16, ., 16, payer, delivering, bloode...
# 1  Eastern Time (US & Canada)          52      -0.112261       -0.170331       3.951244  -0.087836            -0.193240   [Had, to, get, yo, ass, him, until, he, see, it]  [#, comeeeheree, @, DooleyFunnyAf, !, !, ,, @,...
# 2  Eastern Time (US & Canada)         191      -0.111970       -0.159287       5.252273   0.421269             1.579760                [Best, Thanksgiving, memory, share]  [#, ?, @, KnucklePuckIL, theirs…, https, :, //...
# 3  Eastern Time (US & Canada)          24      -0.112669       -0.172061       3.178054  -0.039578            -0.071240                     [rt, for, Seconds, of, Summer]                             [5sos, #, MTVStars, 5]
# 4  Eastern Time (US & Canada)         501      -0.101193       -0.148984       6.216606   0.091428             0.162538  [Why, did, you, do, your, homework, over, the,...      [``, n't, ?, '', https, :, //t.co/L4q1XbK3yq]

# %%
from statsmodels.formula.api import glm, ols
formula = 'logpopularity ~ hashtags + url_count + mention_count + user_follower_count + sentimentnoneutrals + created_at'
model = ols(formula, dftouse.head(2000)).fit()
print "R^2:", model.rsquared
# Out:
# R^2: 0.969061471291

# %%
dir(model)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_data_attr',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'diagn',
#  'eigenvals',
#  'el_test',
#  'ess',
#  'f_pvalue',
#  'f_test',
#  'fittedvalues',
#  'fvalue',
#  'get_influence',
#  'get_robustcov_results',
#  'initialize',
#  'k_constant',
#  'llf',
#  'load',
#  'model',
#  'mse_model',
#  'mse_resid',
#  'mse_total',
#  'nobs',
#  'normalized_cov_params',
#  'outlier_test',
#  'params',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid',
#  'resid_pearson',
#  'rsquared',
#  'rsquared_adj',
#  'save',
#  'scale',
#  'ssr',
#  'summary',
#  'summary2',
#  't_test',
#  'tvalues',
#  'uncentered_tss',
#  'use_t',
#  'wald_test',
#  'wresid']

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          logpopularity   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.835
# Method:                 Least Squares   F-statistic:                     7.233
# Date:                Tue, 08 Dec 2015   Prob (F-statistic):           8.29e-87
# Time:                        16:35:07   Log-Likelihood:                -1658.3
# No. Observations:                2000   AIC:                             6567.
# Df Residuals:                     375   BIC:                         1.567e+04
# Df Model:                        1624
# Covariance Type:            nonrobust
# ==========================================================================================================================================================================================================
#                                                                                                                                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                                                                -17.1930      4.203     -4.091      0.000       -25.457    -8.929
# hashtags[T.[u'100FACES']]                                                                                                                  9.5250      2.186      4.358      0.000         5.227    13.823
# hashtags[T.[u'1DWelcomeToColombia', u'MTVStars']]                                                                                          1.6631      1.833      0.907      0.365        -1.941     5.267
# hashtags[T.[u'4thPrecinctShutDown', u'Minneapolis', u'commUNITY']]                                                                         9.1341      2.197      4.158      0.000         4.815    13.453
# hashtags[T.[u'4thPrecinctShutDown']]                                                                                                      14.0995      2.865      4.921      0.000         8.466    19.733
# hashtags[T.[u'6YearsOfOneTime']]                                                                                                          15.3488      2.753      5.576      0.000         9.936    20.762
# hashtags[T.[u'6thsenseradio']]                                                                                                             9.1295      2.196      4.157      0.000         4.811    13.448
# hashtags[T.[u'9daystilldearsanta', u'seostagram']]                                                                                        11.7501      2.225      5.281      0.000         7.375    16.125
# hashtags[T.[u'ALDUBApproval', u'MarimarSergioLigawan']]                                                                                   10.7373      2.196      4.890      0.000         6.420    15.055
# hashtags[T.[u'ALDUBApproval']]                                                                                                             0.5185      0.695      0.745      0.456        -0.849     1.886
# hashtags[T.[u'AMAs', u'MTVStars']]                                                                                                         3.7277      1.212      3.075      0.002         1.344     6.111
# hashtags[T.[u'AMAs']]                                                                                                                     11.7948      2.167      5.442      0.000         7.533    16.057
# hashtags[T.[u'AMAs1D', u'AMAs']]                                                                                                          13.2197      2.145      6.164      0.000         9.002    17.437
# hashtags[T.[u'AMAs1D']]                                                                                                                   14.3157      2.142      6.682      0.000        10.103    18.528
# hashtags[T.[u'ARIAS5SOS', u'MTVStars', u'VideoMTV2015']]                                                                                   9.8445      2.118      4.648      0.000         5.680    14.009
# hashtags[T.[u'ARMYSelcaDay']]                                                                                                             10.5730      2.200      4.807      0.000         6.248    14.898
# hashtags[T.[u'AamirKhan']]                                                                                                                15.6798      2.865      5.472      0.000        10.046    21.314
# hashtags[T.[u'AliMohammedAlNimr']]                                                                                                         9.7325      2.195      4.434      0.000         5.416    14.049
# hashtags[T.[u'AllyDoesAdele']]                                                                                                            12.8106      2.028      6.318      0.000         8.824    16.797
# hashtags[T.[u'AmandaBlackburn']]                                                                                                          -2.5704      1.858     -1.383      0.167        -6.224     1.083
# hashtags[T.[u'AmericaTrends', u'DrGina']]                                                                                                  9.2120      2.125      4.336      0.000         5.034    13.390
# hashtags[T.[u'AppleCup', u'BeatUW']]                                                                                                      10.3647      2.197      4.718      0.000         6.045    14.685
# hashtags[T.[u'AsSoonAsIEscaped']]                                                                                                         11.9568      2.557      4.677      0.000         6.929    16.984
# hashtags[T.[u'AskTaylor']]                                                                                                                11.4496      2.180      5.251      0.000         7.163    15.737
# hashtags[T.[u'Aurora', u'NorthernLights']]                                                                                                10.7348      2.197      4.886      0.000         6.415    15.055
# hashtags[T.[u'B9']]                                                                                                                       11.1067      2.183      5.087      0.000         6.814    15.400
# hashtags[T.[u'BCBSIL', u'UHC']]                                                                                                            9.3154      2.198      4.238      0.000         4.993    13.638
# hashtags[T.[u'BTS']]                                                                                                                       1.7478      1.913      0.913      0.362        -2.014     5.510
# hashtags[T.[u'BadboymeetBadgirlsLiveinBKK']]                                                                                               1.6133      1.830      0.881      0.379        -1.986     5.213
# hashtags[T.[u'Bae']]                                                                                                                      12.5831      2.198      5.724      0.000         8.261    16.906
# hashtags[T.[u'Bapuji']]                                                                                                                   11.1467      2.193      5.084      0.000         6.836    15.458
# hashtags[T.[u'Beauty', u'Love']]                                                                                                           8.1652      1.659      4.921      0.000         4.902    11.428
# hashtags[T.[u'BeingMaryJane', u'MJsBirthday', u'ALLIDoIsWin']]                                                                             8.8846      2.190      4.057      0.000         4.579    13.191
# hashtags[T.[u'BeingMaryJane']]                                                                                                            14.3672      3.198      4.493      0.000         8.079    20.655
# hashtags[T.[u'BigTicket']]                                                                                                                11.1520      2.201      5.066      0.000         6.824    15.480
# hashtags[T.[u'Biker', u'esctoys', u'kickstarter']]                                                                                        10.3660      2.210      4.690      0.000         6.020    14.712
# hashtags[T.[u'Birmingham', u'android', u'hotguys', u'date']]                                                                               8.7612      2.223      3.941      0.000         4.390    13.132
# hashtags[T.[u'BlackLivesMatter', u'tcot', u'RedNationRising']]                                                                            10.4879      2.219      4.726      0.000         6.124    14.852
# hashtags[T.[u'BlackOps3', u'nuketown']]                                                                                                    8.6270      2.199      3.924      0.000         4.304    12.950
# hashtags[T.[u'Blessed']]                                                                                                                  11.1379      2.211      5.037      0.000         6.790    15.485
# hashtags[T.[u'BlueMile']]                                                                                                                 10.6184      2.197      4.834      0.000         6.299    14.937
# hashtags[T.[u'BookNerdProblems']]                                                                                                         10.8129      2.213      4.886      0.000         6.461    15.165
# hashtags[T.[u'BootOutSnapdeal']]                                                                                                          13.6820      2.845      4.809      0.000         8.088    19.276
# hashtags[T.[u'Buhari', u'military', u'crush', u'unarmed', u'peaceful', u'protesters', u'IPOB', u'FREE', u'NNAMDIKANU', u'BIAFRA']]        11.6905      2.190      5.338      0.000         7.384    15.997
# hashtags[T.[u'CIR', u'ImmigrationSystem', u'TNTVote', u'AINF']]                                                                           10.9664      2.189      5.009      0.000         6.662    15.271
# hashtags[T.[u'CMTTornadoHunters']]                                                                                                         1.2026      1.817      0.662      0.508        -2.369     4.775
# hashtags[T.[u'COP21']]                                                                                                                    11.3223      2.191      5.167      0.000         7.014    15.631
# hashtags[T.[u'CamcorderApp']]                                                                                                             11.4081      2.181      5.231      0.000         7.120    15.696
# hashtags[T.[u'CelebritiesOnlyHispanicPeopleKnow']]                                                                                        12.8844      2.195      5.871      0.000         8.569    17.200
# hashtags[T.[u'ChampionshipBound']]                                                                                                        -0.3086      1.602     -0.193      0.847        -3.459     2.842
# hashtags[T.[u'ChaosLivesHere']]                                                                                                           -3.9325      1.840     -2.137      0.033        -7.551    -0.314
# hashtags[T.[u'ChicagoFire']]                                                                                                               1.3179      1.454      0.906      0.365        -1.542     4.177
# hashtags[T.[u'ChicagoMed', u'ChicagoFire']]                                                                                               10.6901      2.196      4.868      0.000         6.372    15.008
# hashtags[T.[u'CivilWar']]                                                                                                                 10.5023      1.720      6.105      0.000         7.120    13.885
# hashtags[T.[u'Clutch', u'Bonnies']]                                                                                                       -0.5942      1.658     -0.358      0.720        -3.855     2.667
# hashtags[T.[u'CondomChallenge']]                                                                                                          12.1412      2.195      5.531      0.000         7.825    16.457
# hashtags[T.[u'CookieEggchange']]                                                                                                           9.4840      2.184      4.343      0.000         5.190    13.778
# hashtags[T.[u'DWP']]                                                                                                                      -0.7899      1.833     -0.431      0.667        -4.394     2.814
# hashtags[T.[u'DWTS']]                                                                                                                      6.0328      1.580      3.818      0.000         2.926     9.140
# hashtags[T.[u'DWTSFinale', u'Hellblazers', u'BringBackConstantine']]                                                                       0.2136      1.544      0.138      0.890        -2.822     3.249
# hashtags[T.[u'DWTSFinale']]                                                                                                                0.8557      1.854      0.462      0.645        -2.790     4.501
# hashtags[T.[u'DangwaStranded']]                                                                                                           -0.7828      1.491     -0.525      0.600        -3.715     2.150
# hashtags[T.[u'DelhiGovernance']]                                                                                                           5.8708      1.695      3.464      0.001         2.538     9.203
# hashtags[T.[u'Delirium']]                                                                                                                  8.7281      1.773      4.922      0.000         5.241    12.215
# hashtags[T.[u'DontJudgeChallenge']]                                                                                                       11.6504      2.198      5.301      0.000         7.329    15.972
# hashtags[T.[u'Dubs', u'DubNation']]                                                                                                        5.5798      1.480      3.771      0.000         2.670     8.489
# hashtags[T.[u'EADT435', u'FF_Special\u30c4']]                                                                                             11.5735      2.177      5.316      0.000         7.293    15.854
# hashtags[T.[u'ESEA', u'CommonCore', u'StopESEA', u'PJNET']]                                                                               12.8764      2.891      4.453      0.000         7.191    18.562
# hashtags[T.[u'EnergyAnalysis', u'Insight360']]                                                                                             9.6648      2.210      4.373      0.000         5.319    14.010
# hashtags[T.[u'Essential', u'SelfCare', u'Activists', u'Nurture', u'Always']]                                                              12.0666      2.184      5.525      0.000         7.772    16.361
# hashtags[T.[u'EurekaMag']]                                                                                                                11.0356      2.176      5.072      0.000         6.757    15.314
# hashtags[T.[u'EvolutionDay']]                                                                                                             -0.5258      1.569     -0.335      0.738        -3.610     2.558
# hashtags[T.[u'ExoluXioninMacau', u'DO', u'kyungsoo', u'\uacbd\uc218', u'\ub514\uc624']]                                                   11.6568      2.202      5.294      0.000         7.327    15.987
# hashtags[T.[u'ExpresoRadi\xf3nica', u'Estrenos']]                                                                                          9.2417      2.154      4.290      0.000         5.006    13.478
# hashtags[T.[u'F4F', u'MGWV', u'RT2GAIN', u'FOLLOWTRICK', u'FOLLOW']]                                                                       8.5231      1.657      5.144      0.000         5.265    11.781
# hashtags[T.[u'FANX16']]                                                                                                                   11.1506      2.223      5.016      0.000         6.780    15.522
# hashtags[T.[u'FREE']]                                                                                                                     13.7448      2.655      5.176      0.000         8.523    18.966
# hashtags[T.[u'Fallout4']]                                                                                                                 11.0826      2.200      5.038      0.000         6.757    15.408
# hashtags[T.[u'FanChoiceAwards']]                                                                                                          10.2310      2.209      4.633      0.000         5.888    14.574
# hashtags[T.[u'FavoriteHungerGamesMoment']]                                                                                                -0.0217      1.811     -0.012      0.990        -3.583     3.540
# hashtags[T.[u'FilAmAZ']]                                                                                                                   9.3151      2.223      4.189      0.000         4.943    13.687
# hashtags[T.[u'GLVCmbb', u'FlightOn']]                                                                                                      1.5772      1.819      0.867      0.386        -2.000     5.154
# hashtags[T.[u'GOT7', u'Jackson']]                                                                                                         11.2714      2.213      5.094      0.000         6.921    15.622
# hashtags[T.[u'GRAMMYs', u'MTVStars']]                                                                                                     14.7969      2.865      5.165      0.000         9.164    20.430
# hashtags[T.[u'GRAMMYs']]                                                                                                                  12.0439      2.184      5.515      0.000         7.750    16.338
# hashtags[T.[u'Gamecocks']]                                                                                                                10.9613      2.222      4.933      0.000         6.592    15.331
# hashtags[T.[u'Gators', u'WillMuschampField']]                                                                                             10.6503      2.197      4.848      0.000         6.331    14.970
# hashtags[T.[u'Gemini', u'Sagittarius', u'Aquarius', u'Aries']]                                                                            10.6375      2.073      5.132      0.000         6.562    14.713
# hashtags[T.[u'GoBulls']]                                                                                                                  10.2590      2.030      5.054      0.000         6.267    14.251
# hashtags[T.[u'GoCougs', u'BYUWVB', u'WhyNotMore']]                                                                                         0.6941      1.608      0.432      0.666        -2.467     3.855
# hashtags[T.[u'HailState']]                                                                                                                10.3700      2.189      4.737      0.000         6.066    14.674
# hashtags[T.[u'HalaMadrid', u'RMUCL']]                                                                                                     10.7389      2.183      4.920      0.000         6.447    15.030
# hashtags[T.[u'HappyThanksgiving']]                                                                                                        11.3500      2.172      5.227      0.000         7.080    15.620
# hashtags[T.[u'HealthyThanksgiving']]                                                                                                      -0.5629      1.815     -0.310      0.757        -4.132     3.007
# hashtags[T.[u'IARTG']]                                                                                                                    -3.3378      1.840     -1.814      0.070        -6.955     0.279
# hashtags[T.[u'ISIS']]                                                                                                                     11.5301      2.107      5.471      0.000         7.386    15.674
# hashtags[T.[u'IfItAintFunItAintWorthIt']]                                                                                                 11.1214      2.132      5.217      0.000         6.930    15.313
# hashtags[T.[u'IfLovingYouIsWrong']]                                                                                                       -1.1072      1.816     -0.610      0.542        -4.678     2.464
# hashtags[T.[u'Jesus']]                                                                                                                    10.0051      2.196      4.557      0.000         5.688    14.322
# hashtags[T.[u'JustDoIt']]                                                                                                                  9.2766      2.196      4.224      0.000         4.958    13.595
# hashtags[T.[u'Justice4Jamar', u'JusticeForJamar']]                                                                                         9.8686      2.196      4.493      0.000         5.550    14.187
# hashtags[T.[u'JusticeForProsenjit', u'RashtrapatiBhvn', u'smritiirani']]                                                                  13.4171      2.901      4.625      0.000         7.713    19.121
# hashtags[T.[u'JusticeForProsenjit']]                                                                                                       2.2968      1.616      1.421      0.156        -0.881     5.475
# hashtags[T.[u'KAI', u'\uae40\uc885\uc778', u'\u30ab\u30a4', u'EXO']]                                                                       1.8111      1.862      0.973      0.331        -1.851     5.473
# hashtags[T.[u'KELSIANDDAGGER', u'Adabella', u'Fashion', u'Ankle', u'Leather', u'Boots']]                                                   9.3817      2.215      4.235      0.000         5.026    13.737
# hashtags[T.[u'Kimmel', u'Irresistible', u'ABC']]                                                                                          11.8391      2.116      5.595      0.000         7.679    16.000
# hashtags[T.[u'Kimmel', u'JessicaJones', u'ABC']]                                                                                          11.9043      2.116      5.626      0.000         7.744    16.065
# hashtags[T.[u'LHHNY']]                                                                                                                    12.1360      2.221      5.464      0.000         7.769    16.503
# hashtags[T.[u'LOLakers', u'LetsGoWarriors', u'BeatLA', u'FuckLA', u'DubNation', u'GSWChamps']]                                             9.7794      2.196      4.453      0.000         5.461    14.098
# hashtags[T.[u'Landscape', u'Photo', u'LandscapePhotography', u'Photography', u'PhotoOfTheDay']]                                           10.9383      2.195      4.983      0.000         6.622    15.254
# hashtags[T.[u'LaquanMcDonald', u'JasonVanDyke']]                                                                                           9.1481      2.197      4.164      0.000         4.828    13.468
# hashtags[T.[u'LaquanMcDonald', u'sickofthesehashtags']]                                                                                   10.3872      2.197      4.728      0.000         6.067    14.707
# hashtags[T.[u'LaquanMcDonald']]                                                                                                            1.2131      1.282      0.946      0.345        -1.309     3.735
# hashtags[T.[u'Lebanon', u'EU', u'Europe', u'EuropeanUnion', u'FreePalestine', u'Israel', u'Palestine']]                                    8.9238      2.196      4.064      0.000         4.606    13.242
# hashtags[T.[u'LetsRoll']]                                                                                                                 11.7476      2.104      5.583      0.000         7.610    15.885
# hashtags[T.[u'LionPride']]                                                                                                                10.1576      2.202      4.612      0.000         5.827    14.488
# hashtags[T.[u'MGWV']]                                                                                                                     12.0690      2.168      5.566      0.000         7.806    16.332
# hashtags[T.[u'MILFS', u'milfdeepthroat']]                                                                                                  3.8568      1.849      2.086      0.038         0.220     7.493
# hashtags[T.[u'MJsBirthday', u'BeingMaryJane']]                                                                                             2.3449      1.967      1.192      0.234        -1.522     6.212
# hashtags[T.[u'MJsBirthday']]                                                                                                               2.0165      1.821      1.108      0.269        -1.563     5.596
# hashtags[T.[u'MLBNHotStove']]                                                                                                              9.7926      2.140      4.575      0.000         5.584    14.001
# hashtags[T.[u'MR']]                                                                                                                       10.1826      2.196      4.638      0.000         5.865    14.500
# hashtags[T.[u'MSG2MSG2inPunjab', u'SaiMastanaJi']]                                                                                        15.8202      2.789      5.672      0.000        10.336    21.305
# hashtags[T.[u'MSG2MSG2inPunjab']]                                                                                                         14.5736      2.860      5.096      0.000         8.951    20.196
# hashtags[T.[u'MSNBC', u'LaquanMcDonald']]                                                                                                 11.3227      2.196      5.156      0.000         7.005    15.641
# hashtags[T.[u'MTV']]                                                                                                                       8.8885      2.190      4.058      0.000         4.582    13.195
# hashtags[T.[u'MTVSTARS']]                                                                                                                  8.6008      2.197      3.915      0.000         4.281    12.921
# hashtags[T.[u'MTVStars', u'1DVoteAttack']]                                                                                                10.1777      2.197      4.632      0.000         5.857    14.498
# hashtags[T.[u'MTVStars', u'VideoMTV2015', u'GRAMMYs']]                                                                                     9.3119      2.198      4.237      0.000         4.990    13.634
# hashtags[T.[u'MTVStars', u'VideoMTV2015']]                                                                                                -0.9122      1.487     -0.614      0.540        -3.835     2.011
# hashtags[T.[u'MTVStars']]                                                                                                                 -1.1217      0.766     -1.465      0.144        -2.627     0.384
# hashtags[T.[u'MTVstars']]                                                                                                                  9.9919      2.197      4.548      0.000         5.672    14.312
# hashtags[T.[u'MadeInTheAM']]                                                                                                               7.2910      1.593      4.576      0.000         4.158    10.424
# hashtags[T.[u'MadsGilbert', u'Amman', u'BDSJordan']]                                                                                      11.6469      2.193      5.312      0.000         7.335    15.958
# hashtags[T.[u'Mallala', u'PineryFire']]                                                                                                    0.0941      1.536      0.061      0.951        -2.926     3.114
# hashtags[T.[u'Mark', u'GOT7', u'\ub9c8\ud06c', u'\uac13\uc138\ube10']]                                                                    12.6855      2.188      5.799      0.000         8.384    16.987
# hashtags[T.[u'MasitaKyu', u'Kyuhyun']]                                                                                                    11.9644      2.190      5.464      0.000         7.659    16.270
# hashtags[T.[u'MasitaKyu']]                                                                                                                10.6522      2.205      4.831      0.000         6.317    14.988
# hashtags[T.[u'MauiInvitational']]                                                                                                         10.4340      2.167      4.816      0.000         6.174    14.694
# hashtags[T.[u'McCafeFreeCoffee']]                                                                                                         12.1841      2.217      5.495      0.000         7.824    16.544
# hashtags[T.[u'MedalOfFreedom']]                                                                                                            7.2233      1.629      4.434      0.000         4.020    10.427
# hashtags[T.[u'MockingjayPart2']]                                                                                                           4.0167      1.843      2.179      0.030         0.392     7.641
# hashtags[T.[u'MorallyComplicatedYA']]                                                                                                     10.7781      2.197      4.907      0.000         6.459    15.097
# hashtags[T.[u'NANA', u'LIZZY']]                                                                                                           10.5163      2.222      4.732      0.000         6.147    14.886
# hashtags[T.[u'NEW', u'GRAMMYs', u'MTVStars']]                                                                                             10.7616      2.197      4.898      0.000         6.442    15.082
# hashtags[T.[u'NHLDucks', u'IronCogs', u'LetsGoDucks']]                                                                                    10.8176      2.163      5.001      0.000         6.564    15.071
# hashtags[T.[u'NP', u'ListenLive']]                                                                                                         9.6894      2.212      4.380      0.000         5.340    14.039
# hashtags[T.[u'NXT']]                                                                                                                      12.2060      2.208      5.528      0.000         7.864    16.548
# hashtags[T.[u'NYC']]                                                                                                                      10.1789      2.223      4.579      0.000         5.808    14.550
# hashtags[T.[u'NepalNow', u'Nepal', u'UnitedPlanet', u'StillSmiling']]                                                                     10.8251      2.199      4.924      0.000         6.502    15.148
# hashtags[T.[u'New']]                                                                                                                       2.4341      0.997      2.441      0.015         0.473     4.395
# hashtags[T.[u'News', u'almalki']]                                                                                                         11.9551      2.218      5.389      0.000         7.593    16.317
# hashtags[T.[u'NiggaYouBroke']]                                                                                                             9.8239      2.198      4.469      0.000         5.501    14.147
# hashtags[T.[u'NonEntity']]                                                                                                                11.7246      2.174      5.393      0.000         7.450    15.999
# hashtags[T.[u'NowPH']]                                                                                                                    11.2352      2.198      5.113      0.000         6.914    15.556
# hashtags[T.[u'OTTvsDAL']]                                                                                                                 10.5222      2.175      4.837      0.000         6.245    14.800
# hashtags[T.[u'OTWOLFaceOff']]                                                                                                              1.0397      2.226      0.467      0.641        -3.338     5.417
# hashtags[T.[u'OnceUponATime']]                                                                                                            11.3150      2.189      5.169      0.000         7.011    15.619
# hashtags[T.[u'OnlyOnW']]                                                                                                                  10.0767      2.207      4.566      0.000         5.737    14.416
# hashtags[T.[u'Organic']]                                                                                                                   4.9734      1.740      2.858      0.005         1.551     8.395
# hashtags[T.[u'Outrigger']]                                                                                                                 9.9782      2.181      4.576      0.000         5.691    14.266
# hashtags[T.[u'PAKvsENG', u'UAE']]                                                                                                          8.5936      2.196      3.914      0.000         4.276    12.911
# hashtags[T.[u'PPWGxng']]                                                                                                                  12.9740      2.864      4.531      0.000         7.343    18.605
# hashtags[T.[u'PS4', u'TacoBell']]                                                                                                          3.6228      1.845      1.963      0.050        -0.005     7.251
# hashtags[T.[u'PURPOSE']]                                                                                                                 -29.2112      4.027     -7.253      0.000       -37.130   -21.292
# hashtags[T.[u'PURPOSETOUR']]                                                                                                               8.6060      2.197      3.917      0.000         4.286    12.926
# hashtags[T.[u'PandaExpress', u'filmmaker', u'fortunecookie', u'cool', u'FollowMe', u'TrendingNow']]                                        9.1368      2.226      4.105      0.000         4.760    13.513
# hashtags[T.[u'ParisAttacks']]                                                                                                             15.0119      2.860      5.248      0.000         9.387    20.636
# hashtags[T.[u'Periscope', u'VoyAOlvidarte']]                                                                                               9.4011      2.190      4.292      0.000         5.094    13.708
# hashtags[T.[u'Periscope', u'muskoka']]                                                                                                     9.0556      2.217      4.085      0.000         4.696    13.415
# hashtags[T.[u'Periscope']]                                                                                                                10.0277      2.169      4.623      0.000         5.763    14.293
# hashtags[T.[u'PinkMEMORYtourLA', u'PinkMEMORYtour']]                                                                                       0.5712      1.656      0.345      0.730        -2.686     3.828
# hashtags[T.[u'Pisces']]                                                                                                                    5.9116      1.557      3.796      0.000         2.850     8.973
# hashtags[T.[u'PrettyStrong']]                                                                                                              8.8415      2.183      4.049      0.000         4.548    13.135
# hashtags[T.[u'Quinoa', u'Recipe']]                                                                                                         9.8641      2.209      4.464      0.000         5.520    14.209
# hashtags[T.[u'QuoteoftheDay']]                                                                                                            11.1493      2.228      5.005      0.000         6.769    15.529
# hashtags[T.[u'RAPcontest', u'retweet', u'originalsong', u'traprap', u'dope']]                                                              9.3647      2.214      4.230      0.000         5.011    13.718
# hashtags[T.[u'REPOST']]                                                                                                                   10.1185      1.726      5.862      0.000         6.725    13.512
# hashtags[T.[u'RaceAndReality']]                                                                                                           -1.0949      0.945     -1.158      0.248        -2.954     0.764
# hashtags[T.[u'RebeccaBlackSlayBells']]                                                                                                    10.9078      2.083      5.236      0.000         6.812    15.004
# hashtags[T.[u'Rick2016']]                                                                                                                 10.7636      2.176      4.946      0.000         6.484    15.043
# hashtags[T.[u'SJCMBB', u'd3h']]                                                                                                            8.8495      2.189      4.042      0.000         4.545    13.154
# hashtags[T.[u'SMROOKIESSHOW']]                                                                                                             9.4152      2.197      4.285      0.000         5.095    13.736
# hashtags[T.[u'STEM', u'Education']]                                                                                                        0.7587      1.505      0.504      0.614        -2.201     3.718
# hashtags[T.[u'SWEDEN', u'REFUGEES', u'RAPE']]                                                                                             10.4242      2.195      4.749      0.000         6.108    14.741
# hashtags[T.[u'SaiMastanaJi', u'MSG2MSG2inPunjab']]                                                                                        11.0518      2.216      4.988      0.000         6.695    15.409
# hashtags[T.[u'SaiMastanaJi']]                                                                                                             17.4932      3.485      5.019      0.000        10.640    24.347
# hashtags[T.[u'Scotcoin']]                                                                                                                  9.7508      2.217      4.398      0.000         5.391    14.110
# hashtags[T.[u'ScreamQueens']]                                                                                                              3.7206      1.458      2.552      0.011         0.854     6.588
# hashtags[T.[u'SexPistols']]                                                                                                               10.9114      2.195      4.970      0.000         6.595    15.228
# hashtags[T.[u'SexyMommasFromJapan']]                                                                                                      12.7516      2.221      5.740      0.000         8.384    17.120
# hashtags[T.[u'Share', u'RT', u'Yoga']]                                                                                                    10.4198      2.199      4.739      0.000         6.097    14.743
# hashtags[T.[u'ShareTheLove']]                                                                                                              9.4459      2.181      4.331      0.000         5.157    13.735
# hashtags[T.[u'ShowtimeDayMoTo']]                                                                                                          -0.4925      0.938     -0.525      0.600        -2.336     1.351
# hashtags[T.[u'ShowtimeExperience']]                                                                                                       11.8346      2.197      5.387      0.000         7.515    16.154
# hashtags[T.[u'Society']]                                                                                                                   1.3913      1.834      0.759      0.449        -2.215     4.998
# hashtags[T.[u'SomosNERVO', u'NERVOargentina']]                                                                                             3.8084      1.788      2.130      0.034         0.292     7.324
# hashtags[T.[u'SonyMusicSupportsRape']]                                                                                                    13.6420      2.197      6.211      0.000         9.323    17.961
# hashtags[T.[u'SoundCloud', u'np']]                                                                                                         8.4411      1.828      4.616      0.000         4.846    12.036
# hashtags[T.[u'Srinagar', u'Urgent', u'blood']]                                                                                            10.8966      2.178      5.002      0.000         6.613    15.180
# hashtags[T.[u'StarWars']]                                                                                                                  1.7196      1.925      0.893      0.372        -2.066     5.505
# hashtags[T.[u'Stefano', u'AmericanIdol', u'DWTS', u'FeliciaBarton']]                                                                       8.9588      2.197      4.078      0.000         4.639    13.279
# hashtags[T.[u'StopTPP']]                                                                                                                   8.7882      2.226      3.949      0.000         4.412    13.164
# hashtags[T.[u'SweetSixteen']]                                                                                                              9.4545      2.191      4.314      0.000         5.146    13.763
# hashtags[T.[u'SyrianRefugees', u'refugeeswelcome']]                                                                                       10.4721      2.198      4.764      0.000         6.150    14.794
# hashtags[T.[u'TLOS', u'RedsRoyalty', u'OMGDiaries']]                                                                                      10.0228      2.193      4.570      0.000         5.710    14.335
# hashtags[T.[u'TWDRP']]                                                                                                                    -0.0175      1.811     -0.010      0.992        -3.579     3.544
# hashtags[T.[u'Tech', u'almalki']]                                                                                                         11.9721      2.218      5.397      0.000         7.610    16.334
# hashtags[T.[u'ThanksGivingWithWhiteFamilies']]                                                                                             6.5639      1.696      3.871      0.000         3.230     9.898
# hashtags[T.[u'Thanksgiving', u'December', u'CHRISTMAS', u'NewYear']]                                                                       1.1243      1.813      0.620      0.535        -2.440     4.689
# hashtags[T.[u'Thanksgiving', u'Hearties']]                                                                                                 1.4058      1.814      0.775      0.439        -2.161     4.973
# hashtags[T.[u'Thanksgiving']]                                                                                                             17.1833      3.203      5.365      0.000        10.885    23.482
# hashtags[T.[u'ThanksgivingClapBack']]                                                                                                      4.4437      0.982      4.526      0.000         2.513     6.374
# hashtags[T.[u'ThanksgivingClapback']]                                                                                                     15.6377      2.867      5.455      0.000        10.000    21.275
# hashtags[T.[u'ThanksgivingWithBlackFamilies']]                                                                                             1.0781      1.305      0.826      0.409        -1.488     3.645
# hashtags[T.[u'ThanksgivingWithHispanics']]                                                                                                20.8148      3.531      5.895      0.000        13.872    27.758
# hashtags[T.[u'ThanksgivingWithMexicanFamilies']]                                                                                          12.2119      2.188      5.581      0.000         7.909    16.515
# hashtags[T.[u'ThanksgivingWithMexicanfamilies']]                                                                                          11.9836      2.189      5.473      0.000         7.679    16.289
# hashtags[T.[u'ThanksgivingWithWhiteFamilies']]                                                                                            21.1900      3.600      5.887      0.000        14.112    28.268
# hashtags[T.[u'TheHeadHuntersCalling', u'JaiHo']]                                                                                           8.8299      1.774      4.978      0.000         5.342    12.317
# hashtags[T.[u'TheUniverse']]                                                                                                               9.3064      2.223      4.187      0.000         4.936    13.677
# hashtags[T.[u'TheXFiles201Days']]                                                                                                         11.5567      2.193      5.269      0.000         7.244    15.869
# hashtags[T.[u'TonyAbbottIn']]                                                                                                              9.6064      2.197      4.373      0.000         5.287    13.926
# hashtags[T.[u'TrumpIsRight', u'TrumpWillWin', u'PeoplesPresident', u'tcot', u'ccot', u'tcot', u'CruzCrew']]                                9.3068      2.223      4.187      0.000         4.936    13.677
# hashtags[T.[u'UAAPSeason78', u'McDoBonFriesFEU', u'McDoBonFriesUST']]                                                                     12.2431      2.171      5.640      0.000         7.975    16.511
# hashtags[T.[u'Udemy', u'enterprise', u'architect']]                                                                                        9.1215      2.224      4.101      0.000         4.748    13.495
# hashtags[T.[u'Vacation', u'LifeFuel']]                                                                                                    12.9486      2.089      6.198      0.000         8.841    17.056
# hashtags[T.[u'Vedalam', u'Baahubali', u'IMovie', u'SuperHit']]                                                                             1.9375      1.568      1.235      0.217        -1.146     5.021
# ...
# created_at[T.2015-11-25 03:05:43]                                                                                                          4.4921      1.500      2.996      0.003         1.543     7.441
# created_at[T.2015-11-25 03:05:48]                                                                                                         10.2945      2.221      4.634      0.000         5.927    14.662
# created_at[T.2015-11-25 03:05:49]                                                                                                         17.8530      4.262      4.189      0.000         9.472    26.234
# created_at[T.2015-11-25 03:05:50]                                                                                                         17.1973      4.394      3.914      0.000         8.558    25.837
# created_at[T.2015-11-25 03:05:52]                                                                                                          2.8072      1.496      1.876      0.061        -0.135     5.750
# created_at[T.2015-11-25 03:05:54]                                                                                                         17.9735      4.399      4.085      0.000         9.323    26.624
# created_at[T.2015-11-25 03:05:58]                                                                                                         21.0550      4.369      4.820      0.000        12.465    29.645
# created_at[T.2015-11-25 03:06:01]                                                                                                         17.6859      4.272      4.140      0.000         9.285    26.087
# created_at[T.2015-11-25 03:06:03]                                                                                                         17.1739      4.393      3.909      0.000         8.536    25.812
# created_at[T.2015-11-25 03:06:04]                                                                                                         17.3456      4.323      4.012      0.000         8.845    25.846
# created_at[T.2015-11-25 03:06:06]                                                                                                         20.9175      4.402      4.752      0.000        12.262    29.573
# created_at[T.2015-11-25 03:06:07]                                                                                                         18.2044      4.389      4.148      0.000         9.574    26.835
# created_at[T.2015-11-25 03:06:08]                                                                                                          8.6198      2.198      3.922      0.000         4.298    12.941
# created_at[T.2015-11-25 03:06:09]                                                                                                         18.3296      4.460      4.110      0.000         9.560    27.100
# created_at[T.2015-11-25 03:06:10]                                                                                                         18.7115      4.261      4.391      0.000        10.333    27.090
# created_at[T.2015-11-25 03:06:12]                                                                                                         17.4427      4.444      3.925      0.000         8.705    26.181
# created_at[T.2015-11-25 03:06:13]                                                                                                         17.1966      4.394      3.914      0.000         8.558    25.836
# created_at[T.2015-11-25 03:06:14]                                                                                                         17.7127      4.378      4.045      0.000         9.103    26.322
# created_at[T.2015-11-25 03:06:15]                                                                                                         10.6901      2.196      4.868      0.000         6.372    15.008
# created_at[T.2015-11-25 03:06:18]                                                                                                         19.4089      4.368      4.443      0.000        10.819    27.998
# created_at[T.2015-11-25 03:06:19]                                                                                                          9.3143      2.198      4.237      0.000         4.992    13.636
# created_at[T.2015-11-25 03:06:20]                                                                                                         18.2341      4.307      4.234      0.000         9.766    26.702
# created_at[T.2015-11-25 03:06:21]                                                                                                         20.7896      4.240      4.904      0.000        12.453    29.126
# created_at[T.2015-11-25 03:06:23]                                                                                                         22.1514      4.249      5.213      0.000        13.796    30.507
# created_at[T.2015-11-25 03:06:25]                                                                                                         19.9731      4.207      4.747      0.000        11.700    28.246
# created_at[T.2015-11-25 03:06:26]                                                                                                         20.5058      4.383      4.679      0.000        11.888    29.124
# created_at[T.2015-11-25 03:06:27]                                                                                                         17.8794      4.391      4.072      0.000         9.246    26.513
# created_at[T.2015-11-25 03:06:29]                                                                                                         21.9195      4.373      5.012      0.000        13.320    30.519
# created_at[T.2015-11-25 03:06:31]                                                                                                         17.7920      4.381      4.061      0.000         9.177    26.407
# created_at[T.2015-11-25 03:06:32]                                                                                                         18.4060      4.262      4.319      0.000        10.026    26.786
# created_at[T.2015-11-25 03:06:33]                                                                                                         18.0799      4.256      4.248      0.000         9.712    26.448
# created_at[T.2015-11-25 03:06:34]                                                                                                         17.2356      4.396      3.921      0.000         8.593    25.879
# created_at[T.2015-11-25 03:06:36]                                                                                                          9.3100      2.223      4.188      0.000         4.939    13.681
# created_at[T.2015-11-25 03:06:37]                                                                                                         17.3479      4.280      4.053      0.000         8.932    25.764
# created_at[T.2015-11-25 03:06:38]                                                                                                         21.4039      4.367      4.901      0.000        12.817    29.991
# created_at[T.2015-11-25 03:06:39]                                                                                                         17.7607      4.379      4.056      0.000         9.150    26.371
# created_at[T.2015-11-25 03:06:41]                                                                                                         19.6115      4.365      4.493      0.000        11.029    28.194
# created_at[T.2015-11-25 03:06:42]                                                                                                         17.9188      4.395      4.078      0.000         9.278    26.560
# created_at[T.2015-11-25 03:06:43]                                                                                                         19.0508      4.371      4.358      0.000        10.456    27.646
# created_at[T.2015-11-25 03:06:46]                                                                                                         19.4754      4.579      4.253      0.000        10.471    28.480
# created_at[T.2015-11-25 03:06:51]                                                                                                         17.4977      4.443      3.939      0.000         8.762    26.233
# created_at[T.2015-11-25 03:06:54]                                                                                                         10.2590      2.030      5.054      0.000         6.267    14.251
# created_at[T.2015-11-25 03:06:56]                                                                                                         17.8383      4.385      4.068      0.000         9.215    26.461
# created_at[T.2015-11-25 03:06:57]                                                                                                          3.3932      1.357      2.501      0.013         0.726     6.061
# created_at[T.2015-11-25 03:07:03]                                                                                                         17.0409      4.809      3.543      0.000         7.585    26.497
# created_at[T.2015-11-25 03:07:06]                                                                                                          9.2120      2.125      4.336      0.000         5.034    13.390
# created_at[T.2015-11-25 03:07:10]                                                                                                         19.3089      3.967      4.867      0.000        11.508    27.110
# created_at[T.2015-11-25 03:07:11]                                                                                                         17.2371      4.396      3.921      0.000         8.594    25.880
# created_at[T.2015-11-25 03:07:15]                                                                                                         23.4571      4.383      5.351      0.000        14.838    32.076
# created_at[T.2015-11-25 03:07:16]                                                                                                         17.7716      4.380      4.058      0.000         9.160    26.384
# created_at[T.2015-11-25 03:07:17]                                                                                                          9.4011      2.190      4.292      0.000         5.094    13.708
# created_at[T.2015-11-25 03:07:19]                                                                                                         17.2119      4.394      3.917      0.000         8.571    25.852
# created_at[T.2015-11-25 03:07:22]                                                                                                         17.2355      4.396      3.921      0.000         8.592    25.879
# created_at[T.2015-11-25 03:07:25]                                                                                                         17.7791      4.382      4.057      0.000         9.163    26.396
# created_at[T.2015-11-25 03:07:26]                                                                                                         20.2114      4.233      4.775      0.000        11.889    28.534
# created_at[T.2015-11-25 03:07:27]                                                                                                         17.1786      4.393      3.910      0.000         8.540    25.817
# created_at[T.2015-11-25 03:07:28]                                                                                                          8.8415      2.183      4.049      0.000         4.548    13.135
# created_at[T.2015-11-25 03:07:30]                                                                                                         17.8834      4.393      4.070      0.000         9.244    26.522
# created_at[T.2015-11-25 03:07:31]                                                                                                         11.8316      2.827      4.185      0.000         6.273    17.390
# created_at[T.2015-11-25 03:07:34]                                                                                                          3.0607      1.359      2.253      0.025         0.389     5.732
# created_at[T.2015-11-25 03:07:40]                                                                                                         17.7493      4.379      4.053      0.000         9.139    26.360
# created_at[T.2015-11-25 03:07:43]                                                                                                         17.7724      4.343      4.092      0.000         9.233    26.312
# created_at[T.2015-11-25 03:07:51]                                                                                                         18.9623      4.388      4.321      0.000        10.334    27.591
# created_at[T.2015-11-25 03:07:52]                                                                                                         16.9701      4.293      3.953      0.000         8.528    25.412
# created_at[T.2015-11-25 03:07:54]                                                                                                         17.7769      4.380      4.059      0.000         9.165    26.389
# created_at[T.2015-11-25 03:07:56]                                                                                                         17.8563      4.393      4.065      0.000         9.219    26.494
# created_at[T.2015-11-25 03:08:00]                                                                                                         18.3884      4.374      4.204      0.000         9.788    26.989
# created_at[T.2015-11-25 03:08:01]                                                                                                         18.3040      4.368      4.190      0.000         9.715    26.893
# created_at[T.2015-11-25 03:08:02]                                                                                                         17.2171      4.395      3.918      0.000         8.576    25.858
# created_at[T.2015-11-25 03:08:06]                                                                                                         18.8013      4.392      4.281      0.000        10.166    27.436
# created_at[T.2015-11-25 03:08:15]                                                                                                          3.0207      1.358      2.225      0.027         0.351     5.690
# url_count                                                                                                                                 -0.3074      0.284     -1.081      0.280        -0.866     0.251
# mention_count                                                                                                                             -0.5522      0.127     -4.337      0.000        -0.802    -0.302
# user_follower_count                                                                                                                     1.244e-06   1.69e-07      7.341      0.000      9.11e-07  1.58e-06
# sentimentnoneutrals                                                                                                                       -0.1147      0.222     -0.516      0.606        -0.552     0.322
# ==============================================================================
# Omnibus:                     1054.223   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            52633.626
# Skew:                          -1.738   Prob(JB):                         0.00
# Kurtosis:                      27.890   Cond. No.                     5.64e+23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 6.31e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# Preliminary test on a basic OLS regression model we have fairly low R^2. It's possible to run the following code to see if there's just something wrong in our formula (i.e. can we get a higher R^2 with a different combination of features), but it's likely that all our results are going to have a low R^2 by the nature of the problem.

# %% [raw]
# ```python
# # final, final version
# import itertools
# formulabase = 'popularity ~ '
# variables = ['hashtags', 'url_count', 'mention_count', 'user_follower_count', 'sentimentnoneutrals', 'date_objects', 'created_at']
# ' + '.join(variables)
#
# testresults = {}
#
# for i in range(1,len(variables)):
#     #print ' + '.join(list(itertools.combinations(variables, i)))
#     for var in list(itertools.combinations(variables, i)):
#         testformula = formulabase + ' + '.join(var)
#         print testformula, "running......"
#         testmodel = ols(testformula, dftouse).fit()
#         testresults[testformula] = testmodel.rsquared

# %%
# this takes forever to run + overheated my laptop
sns.lmplot(x="sentimentnoneutrals", y="popularity", hue="user_follower_count", data=dftouse, size = 7, aspect=1.2)

# %%
# import csv
# another example with Cursor get all tweets with a certain hashtag and a certain time frame within past week 
# csvFile = open('tweets.csv', 'a')
# Use csv Writer
# csvWriter = csv.writer(csvFile)

# for tweet in tweepy.Cursor(api.search,q="#PrayForJapan",count=1,\
#                            lang="en",\
#                            since_id=2015-11-13).items():
#     print tweet.created_at, tweet.text
#     csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])

# %% [markdown]
# ## Prediction Results

# %%
plt.scatter(dftouse['logpopularity'].head(2000), model.predict())
plt.plot([-2,16],[-2,16], 'k', label="slope 1", linewidth=2)
plt.xlim(-1.5,16)
plt.ylim(-1.5,16)
plt.xlabel('Actual Log Popularity Score')
plt.ylabel('Predicted Log Popularity Score')
plt.show()
